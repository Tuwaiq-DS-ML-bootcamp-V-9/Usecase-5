# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

#import ipyvizzu
from ipyvizzu import Chart, Data, Config, Style

from ydata_profiling import ProfileReport
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
Jadarat_data=pd.read_csv("Jadarat_data.csv")

# %%
profile = ProfileReport(Jadarat_data, explorative=True)

# %%
#use Dtale
profile.to_file("Jadarat_data_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 170.33it/s]

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
Jadarat_data.shape
# Out:
# (1470, 18)

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
Jadarat_data.head()
# Out:
#                    job_title    job_date  \
# 0                      محاسب  27/05/1444
# 1                       بائع  27/05/1444
# 2  أخصائي عمليات موارد بشرية  27/05/1444
# 3            ميكانيكي سيارات  27/05/1444
# 4                      محاسب  27/05/1444
#
#                                             job_desc  \
# 0  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2  ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3  ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
#
#                                            job_tasks  \
# 0  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2  ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3  ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
#
# ...

# %%
# job_title: The title of the job position (e.g., Software Engineer, Data Analyst).  
# job_date: The date when the job was posted.  
# job_desc: A description of the job, including responsibilities and expectations.  
# job_tasks: Specific tasks and duties associated with the job.  
# comp_name: The name of the company offering the job.  
# comp_no: Possibly a unique identifier for the company (company number or registration).  
# comp_type: The type of company (e.g., private, government, startup, multinational).  
# comp_size: The size of the company (e.g., small, medium, large).  
# eco_activity:The economic sector or industry in which the company operates (e.g., technology, healthcare).  
# qualif: Required qualifications for the job (e.g., degree, certifications, skills).  
# region: The geographical region where the job is located.  
# city: The specific city where the job is available.  
# benefits: Additional perks provided by the company (e.g., health insurance, remote work, bonuses).  
# contract:Type of job contract (e.g., full-time, part-time, temporary, permanent).  
# positions: Number of open positions available for the job.  
# job_post_id: A unique identifier for the job posting.  
# exper: Required years of experience for the job.  
# gender: Indicates if the job has a gender preference or is open to all genders.  

Jadarat_data.columns
# Out:
# Index(['job_title', 'job_date', 'job_desc', 'job_tasks', 'comp_name',
#        'comp_no', 'comp_type', 'comp_size', 'eco_activity', 'qualif', 'region',
#        'city', 'benefits', 'contract', 'positions', 'job_post_id', 'exper',
#        'gender'],
#       dtype='object')

# %%
Jadarat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     1470 non-null   object
#  1   job_date      1470 non-null   object
#  2   job_desc      1470 non-null   object
#  3   job_tasks     1470 non-null   object
#  4   comp_name     1470 non-null   object
#  5   comp_no       1470 non-null   object
#  6   comp_type     1470 non-null   object
#  7   comp_size     1456 non-null   object
#  8   eco_activity  1380 non-null   object
#  9   qualif        780 non-null    object
#  10  region        1470 non-null   object
#  11  city          1470 non-null   object
#  12  benefits      1470 non-null   object
#  13  contract      1470 non-null   object
#  14  positions     1470 non-null   object
#  15  job_post_id   1470 non-null   int64
#  16  exper         1470 non-null   object
#  17  gender        1470 non-null   object
# ...

# %%
Jadarat_data.describe()
# Out:
#         job_post_id
# count  1.470000e+03
# mean   2.020203e+13
# std    5.863941e+04
# min    2.020203e+13
# 25%    2.020203e+13
# 50%    2.020203e+13
# 75%    2.020203e+13
# max    2.020203e+13

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
 # dataset from Jadarat , trustworth

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
# the data is up-to-date

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
# Company details
# Job descriptions
# Required Qualifications
# Job tasks
# Salary
# Contract details
# Positions available
# Job post ID
# Years of experience required
# Gender
# Region
# City
Jadarat_data.head()
# Out:
#                    job_title    job_date  \
# 0                      محاسب  27/05/1444
# 1                       بائع  27/05/1444
# 2  أخصائي عمليات موارد بشرية  27/05/1444
# 3            ميكانيكي سيارات  27/05/1444
# 4                      محاسب  27/05/1444
#
#                                             job_desc  \
# 0  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2  ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3  ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
#
#                                            job_tasks  \
# 0  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2  ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3  ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
#
# ...

# %%
Jadarat_data.loc[1, 'job_desc']
# Out:
# "['بيع مجموعة من السلع والخدمات للعملاء، وتوفير المعلومات المتعلقة بالمنتجات واستخداماتها وأسعارها، وتولي أمور الدفع وتلقي المدفوعات من العملاء.']"

# %%
#drop job_desc beacuse it's not related to the analysis
Jadarat_data.drop(columns=['job_desc'], inplace=True)

# %%
#drop job_tasks beacuse it's not related to the analysis
Jadarat_data.drop(columns=['job_tasks'], inplace=True)

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
#check the null
Jadarat_data.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Display the one duplicated 
Jadarat_data[Jadarat_data.duplicated(keep=False)]
# Out:
#      job_title    job_date                            comp_name    comp_no  \
# 1467     صيدلي  18/06/1444  شركة تقنية الدواجن والألبان للتجارة  1-2415250
# 1469     صيدلي  18/06/1444  شركة تقنية الدواجن والألبان للتجارة  1-2415250
#
#      comp_type    comp_size eco_activity  \
# 1467       خاص  صغيرة فئة ب          NaN
# 1469       خاص  صغيرة فئة ب          NaN
#
#                                                  qualif  region          city  \
# 1467  ['Professional certificate \\ License data', '...  الرياض  AR RIYADH...
# 1469  ['Professional certificate \\ License data', '...  الرياض  AR RIYADH...
#
#                   benefits   contract positions     job_post_id    exper  \
# 1467  ['Salary', '7000.0']  دوام كامل     0 / 1  20202026399061  0 Years
# 1469  ['Salary', '7000.0']  دوام كامل     0 / 1  20202026399061  0 Years
#
#      gender
# 1467   both
# 1469   both

# %%
Jadarat_data.duplicated('comp_no').sum()
# Out:
# np.int64(576)

# %%
#every comp_name has a uinqe comp_no , normal duplicatee
Jadarat_data[Jadarat_data.duplicated(['comp_no'], keep=False)]
# Out:
#                 job_title    job_date  \
# 3         ميكانيكي سيارات  27/05/1444
# 6           سكرتير تنفيذي  27/05/1444
# 7               مدير مكتب  27/05/1444
# 8     أخصائي إدارة مشاريع  27/05/1444
# 9             مصمم جرافيك  26/05/1444
# ...                   ...         ...
# 1462        سكرتير قانوني  23/06/1444
# 1464                 بائع  21/06/1444
# 1465  مهندس تقنية معلومات  19/06/1444
# 1467                صيدلي  18/06/1444
# 1469                صيدلي  18/06/1444
#
#                                               comp_name     comp_no comp_type  \
# 3                               مؤسسة لمكو لغيار الزيوت   8-1925495       خاص
# 6     شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 7     شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 8     شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 9     شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# ...

# %%
Jadarat_data.duplicated('job_post_id').sum()
# Out:
# np.int64(89)

# %%
Jadarat_data['job_post_id']
# Out:
# 0       20202026350419
# 1       20202026350389
# 2       20202026350347
# 3       20202026350219
# 4       20202026350043
#              ...
# 1465    20202026400353
# 1466    20202026399849
# 1467    20202026399061
# 1468    20202026398972
# 1469    20202026399061
# Name: job_post_id, Length: 1470, dtype: int64

# %%
Jadarat_data[Jadarat_data.duplicated(subset=['job_post_id'], keep=False)]
# Out:
#                       job_title    job_date  \
# 40                     مدير فرع  25/05/1444
# 47                         بائع  25/05/1444
# 48                         بائع  25/05/1444
# 49    أخصائي عمليات موارد بشرية  25/05/1444
# 50            أخصائي خدمة عملاء  25/05/1444
# ...                         ...         ...
# 1389                   كاتب شحن  02/06/1444
# 1457                      محاسب  23/06/1444
# 1458          أخصائي خدمة عملاء  23/06/1444
# 1467                      صيدلي  18/06/1444
# 1469                      صيدلي  18/06/1444
#
#                                               comp_name     comp_no comp_type  \
# 40                                    شركة الزي للتجارة   9-2079452       خاص
# 47                شركة مطعم بيت الشاورما لتقديم الوجبات   1-2239765       خاص
# 48                            شركة أطياب غناتي التجارية  29-1959880       خاص
# 49    شركة الصخرة المشرفة والسارية الخضراء للاستشارا...    1-321449       خاص
# ...

# %%
specific_id = 20202026402465
duplicates = Jadarat_data[Jadarat_data['job_post_id'] == specific_id]
duplicates
# Out:
#               job_title    job_date           comp_name    comp_no comp_type  \
# 1313  أخصائي خدمة عملاء  23/06/1444  شركة بوركت للتجارة  1-2290505       خاص
# 1458  أخصائي خدمة عملاء  23/06/1444  شركة بوركت للتجارة  1-2290505       خاص
#
#         comp_size                                      eco_activity  \
# 1313  صغيرة فئة ب  البيع بالتجزئة لمنتجات المخابز والحلويات السكرية
# 1458  صغيرة فئة ب  البيع بالتجزئة لمنتجات المخابز والحلويات السكرية
#
#                                                  qualif  region          city  \
# 1313  ['Skill data', 'مهارات الإقناع', 'محترف', 'الل...  الرياض  AR RIYADH...
# 1458  ['Skill data', 'مهارات الإقناع', 'محترف', 'الل...  الرياض  AR RIYADH...
#
#                   benefits   contract positions     job_post_id    exper  \
# 1313  ['Salary', '4000.0']  دوام كامل     0 / 5  20202026402465  4 Years
# 1458  ['Salary', '4000.0']  دوام كامل     1 / 5  20202026402465  4 Years
#
#      gender
# 1313   both
# 1458   both

# %%
specific_id = 20202026399061
duplicates = Jadarat_data[Jadarat_data['job_post_id'] == specific_id]
duplicates
# the job_post_id should not be duplicated but it's related to the company name (the same company) 
# Maybe they updated some information later(positions)
# Out:
#      job_title    job_date                            comp_name    comp_no  \
# 1355     صيدلي  18/06/1444  شركة تقنية الدواجن والألبان للتجارة  1-2415250
# 1467     صيدلي  18/06/1444  شركة تقنية الدواجن والألبان للتجارة  1-2415250
# 1469     صيدلي  18/06/1444  شركة تقنية الدواجن والألبان للتجارة  1-2415250
#
#      comp_type    comp_size                                    eco_activity  \
# 1355       خاص  صغيرة فئة ب  بيع الأدوية البيطرية ، يشمل ( معدات البيطرية )
# 1467       خاص  صغيرة فئة ب                                             NaN
# 1469       خاص  صغيرة فئة ب                                             NaN
#
#                                                  qualif  region          city  \
# 1355  ['Professional certificate \\ License data', '...  الرياض  AR RIYADH...
# 1467  ['Professional certificate \\ License data', '...  الرياض  AR RIYADH...
# 1469  ['Professional certificate \\ License data', '...  الرياض  AR RIYADH...
#
# ...

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
Jadarat_data.tail(10)
# Out:
#                 job_title    job_date  \
# 1459    موظف صندوق محاسبة  23/06/1444
# 1460              كيميائي  23/06/1444
# 1461          مساعد إداري  23/06/1444
# 1462        سكرتير قانوني  23/06/1444
# 1463                 بائع  21/06/1444
# 1464                 بائع  21/06/1444
# 1465  مهندس تقنية معلومات  19/06/1444
# 1466               سكرتير  19/06/1444
# 1467                صيدلي  18/06/1444
# 1468  مشغل آلة تشطيب رخام  18/06/1444
#
#                                               comp_name     comp_no comp_type  \
# 1459                         شركة عنان للخدمات الغذائية  23-1946813       خاص
# 1460                       شركة نواف صالح البطي للتجارة   1-2604723       خاص
# 1461  شركة النصرة للمحاماة والاستشارات القانونية شرك...  15-1970732       خاص
# 1462  شركة النصرة للمحاماة والاستشارات القانونية شرك...  15-1970732       خاص
# 1463          مؤسسة مصلح دخيل الله صالح الثبيتي للتجارة    13-13828       خاص
# ...

# %%
#Display number missing values per column
Jadarat_data.isnull().sum()
# Out:
# job_title         0
# job_date          0
# comp_name         0
# comp_no           0
# comp_type         0
# comp_size        14
# eco_activity     89
# qualif          690
# region            0
# city              0
# benefits          0
# contract          0
# positions         0
# job_post_id       0
# exper             0
# gender            0
# dtype: int64

# %%
Jadarat_data[Jadarat_data['comp_size'].isnull()]
# Out:
#                 job_title    job_date  \
# 1296           مدير إداري  25/06/1444
# 1393    موظف صندوق محاسبة  01/07/1444
# 1399    موظف صندوق محاسبة  29/06/1444
# 1401           وسيط عقاري  29/06/1444
# 1409                محامي  29/06/1444
# 1411        أخصائي قانوني  29/06/1444
# 1421            مدير مالي  29/06/1444
# 1426             مصفف شعر  29/06/1444
# 1432    موظف صندوق محاسبة  27/06/1444
# 1436    أخصائي علاج طبيعي  26/06/1444
# 1438                 بائع  26/06/1444
# 1444  مشرف مدخلي البيانات  26/06/1444
# 1451        فني مختبر طبي  25/06/1444
# 1456                محامي  24/06/1444
#
#                                               comp_name     comp_no comp_type  \
# 1296            مكتب تصميم المشاريع للاستشارات الهندسية   4-1990473       خاص
# 1393                            مغاسل نسيم الفل للملابس  15-1963098       خاص
# 1399                            مغاسل نسيم الفل للملابس  15-1963098       خاص
# ...

# %%
#there is missing value
Jadarat_data[Jadarat_data['eco_activity'].isnull()]
# Out:
#                 job_title    job_date  \
# 3         ميكانيكي سيارات  27/05/1444
# 25               مدير عام  26/05/1444
# 40               مدير فرع  25/05/1444
# 42      موظف استقبال فندق  25/05/1444
# 47                   بائع  25/05/1444
# ...                   ...         ...
# 1438                 بائع  26/06/1444
# 1444  مشرف مدخلي البيانات  26/06/1444
# 1451        فني مختبر طبي  25/06/1444
# 1467                صيدلي  18/06/1444
# 1468  مشغل آلة تشطيب رخام  18/06/1444
#
#                                               comp_name     comp_no comp_type  \
# 3                               مؤسسة لمكو لغيار الزيوت   8-1925495       خاص
# 25                ورشة اضواء المشاعل للحدادة والالمنيوم  10-2010602       خاص
# 40                                    شركة الزي للتجارة   9-2079452       خاص
# 42                             فندق قصر الواحة الفندقية   1-2440535       خاص
# 47                شركة مطعم بيت الشاورما لتقديم الوجبات   1-2239765       خاص
# ...

# %%
Jadarat_data[Jadarat_data['qualif'].isnull()]
# Out:
#                       job_title    job_date  \
# 1                          بائع  27/05/1444
# 14                  مصمم جرافيك  26/05/1444
# 15                  مدخل بيانات  26/05/1444
# 16                   مطور برامج  26/05/1444
# 17            أخصائي إدارة اداء  26/05/1444
# ...                         ...         ...
# 1454  أخصائي عمليات موارد بشرية  25/06/1444
# 1455            فني تصميم داخلي  24/06/1444
# 1460                    كيميائي  23/06/1444
# 1464                       بائع  21/06/1444
# 1465        مهندس تقنية معلومات  19/06/1444
#
#                                               comp_name     comp_no comp_type  \
# 1                          شركة عالم الكهرباء للمقاولات   4-1324428       خاص
# 14                      مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 15                      مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 16                      مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# ...

# %%
# all the nan vaule in qualif it is a private comp_type
Jadarat_data[Jadarat_data[['qualif', 'comp_type']].isnull().any(axis=1)].head(60)
# Out:
#                           job_title    job_date  \
# 1                              بائع  27/05/1444
# 14                      مصمم جرافيك  26/05/1444
# 15                      مدخل بيانات  26/05/1444
# 16                       مطور برامج  26/05/1444
# 17                أخصائي إدارة اداء  26/05/1444
# 18                      مدخل بيانات  26/05/1444
# 23               محلل نظم المعلومات  26/05/1444
# 27               كاتب علاقات حكومية  26/05/1444
# 30                      مساعد إداري  25/05/1444
# 32                      فني كيميائي  25/05/1444
# 33                    مهندس كهربائي  25/05/1444
# 34                   مهندس ميكانيكي  25/05/1444
# 35                       مدير إداري  25/05/1444
# 36              فني هندسة ميكانيكية  25/05/1444
# 37               فني هندسة كهربائية  25/05/1444
# 41                             بائع  25/05/1444
# 43                     مندوب مبيعات  25/05/1444
# 45   كاتب استعلامات مركز خدمة عملاء  25/05/1444
# ...

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
Jadarat_data.head(1)
# Out:
#   job_title    job_date                 comp_name   comp_no comp_type  \
# 0     محاسب  27/05/1444  شركة مقر العالم للسفريات  1-317262       خاص
#
#       comp_size                 eco_activity  \
# 0  متوسطة فئة أ  أنشطة وكالات السياحة والسفر
#
#                                            qualif  region          city  \
# 0  ['Language data', 'اللغة الانجليزية', 'محترف']  الرياض  AR RIYADH...
#
#                benefits   contract positions     job_post_id    exper gender
# 0  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350419  0 Years   both

# %%
# check columns types 
Jadarat_data.dtypes
# Out:
# job_title       object
# job_date        object
# comp_name       object
# comp_no         object
# comp_type       object
# comp_size       object
# eco_activity    object
# qualif          object
# region          object
# city            object
# benefits        object
# contract        object
# positions       object
# job_post_id      int64
# exper           object
# gender          object
# dtype: object

# %%
# go to clean them

# %%
# check outliers

# %%
Jadarat_data.head(2)
# Out:
#   job_title    job_date                     comp_name    comp_no comp_type  \
# 0     محاسب  27/05/1444      شركة مقر العالم للسفريات   1-317262       خاص
# 1      بائع  27/05/1444  شركة عالم الكهرباء للمقاولات  4-1324428       خاص
#
#       comp_size                                       eco_activity  \
# 0  متوسطة فئة أ                        أنشطة وكالات السياحة والسفر
# 1  متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
#
#                                            qualif           region  \
# 0  ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                       غير معروف  المنطقة الشرقية
#
#            city              benefits   contract positions     job_post_id  \
# 0  AR RIYADH...  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350419
# 1  AD DAMMAM...  ['Salary', '5000.0']  دوام كامل     0 / 3  20202026350389
#
#      exper gender  Salary
# 0  0 Years   both  5000.0
# 1  0 Years   both  5000.0

# %%
Jadarat_data['region'].value_counts()
# Out:
# region
# الرياض             621
# مكة المكرمة        369
# المنطقة الشرقية    219
# المدينة المنورة     86
# الباحة              46
# عسير                42
# القصيم              32
# حائل                18
# تبوك                11
# نجران                8
# جازان                7
# الجوف                5
# الحدود الشمالية      4
# اخرى                 1
# Name: count, dtype: int64

# %%
#Jadarat_data["region_fixed"] = Jadarat_data["region"].apply(lambda x: get_display(arabic_reshaper.reshape(x)))


plt.figure(figsize=(10, 5))
plt.scatter(Jadarat_data["region"].apply(lambda x: get_display(arabic_reshaper.reshape(x))), Jadarat_data["Salary"], color="blue", alpha=0.5)
plt.xticks(rotation=90) 
plt.title("Salary Distribution by Region")
plt.xlabel("Region")
plt.ylabel("Salary")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(Jadarat_data["exper"], bins=20, kde=True, color="blue")

plt.xlabel("year of Experience")
plt.ylabel("frequency")
plt.title("Experience Distribution")

plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(Jadarat_data["Salary"], bins=10, kde=True, color="blue")

plt.xlabel("Salary")
plt.ylabel("frequency")
plt.title("Salary Distribution")

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.hist(Jadarat_data['job_post_id'], bins=30, color="skyblue", edgecolor="black")
plt.title("Distribution of Job Post IDs")
plt.xlabel("Job Post ID")
plt.ylabel("Frequency")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
#انتشار طبيعي بحكم حجم المنطقه + عدد السكان
# Count the number of job postings per city
city_counts = Jadarat_data['city'].value_counts().head(10)
# Plot the city distribution
plt.figure(figsize=(12, 6))
city_counts.plot(kind="bar", color="lightcoral")
plt.title("Distribution of Job Postings by City")
plt.xlabel("City")
plt.ylabel("Number of Job Postings")
plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

region_counts = Jadarat_data['region'].value_counts().head(10)


title_ar = get_display(arabic_reshaper.reshape("توزيع إعلانات الوظائف حسب المنطقة"))
xlabel_ar = get_display(arabic_reshaper.reshape("المنطقة"))
ylabel_ar = get_display(arabic_reshaper.reshape("عدد إعلانات الوظائف"))

region_labels = [get_display(arabic_reshaper.reshape(region)) for region in region_counts.index]

plt.figure(figsize=(12, 6))
plt.bar(region_labels, region_counts.values, color="lightblue", edgecolor="black")


plt.xlabel(xlabel_ar, fontsize=12)
plt.ylabel(ylabel_ar, fontsize=12)
plt.title(title_ar, fontsize=14)

plt.xticks(rotation=45, ha="right")  
plt.grid(axis="y", linestyle="--", alpha=0.7)


plt.show()

#انتشار طبيعي بحكم حجم المنطقه + عدد السكان

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %%
#cleaing
#drop the duplicated
Jadarat_data = Jadarat_data.drop_duplicates()
Jadarat_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
Jadarat_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# go back to 6th dimention --> Completeness

# %%
#fill the nan with (غير معروف)
Jadarat_data['comp_size'].replace(np.nan, 'غير معروف', inplace=True)
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/1530284913.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Jadarat_data['comp_size'].replace(np.nan, 'غير معروف', inplace=True)
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/1530284913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#check the nan in comp_size
Jadarat_data[Jadarat_data['comp_size'].isnull()]
# Out:
# Empty DataFrame
# Columns: [job_title, job_date, comp_name, comp_no, comp_type, comp_size, eco_activity, qualif, region, city, benefits, contract, positions, job_post_id, exper, gender]
# Index: []

# %%
Jadarat_data.isnull().sum()
# Out:
# job_title         0
# job_date          0
# comp_name         0
# comp_no           0
# comp_type         0
# comp_size         0
# eco_activity     89
# qualif          690
# region            0
# city              0
# benefits          0
# contract          0
# positions         0
# job_post_id       0
# exper             0
# gender            0
# dtype: int64

# %%
Jadarat_data['qualif'].replace(np.nan, 'غير معروف', inplace=True)
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/500221151.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Jadarat_data['qualif'].replace(np.nan, 'غير معروف', inplace=True)
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/500221151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#check the nan in qualif
Jadarat_data[Jadarat_data['qualif'].isnull()]
# Out:
# Empty DataFrame
# Columns: [job_title, job_date, comp_name, comp_no, comp_type, comp_size, eco_activity, qualif, region, city, benefits, contract, positions, job_post_id, exper, gender]
# Index: []

# %%
Jadarat_data.isnull().sum()
# Out:
# job_title        0
# job_date         0
# comp_name        0
# comp_no          0
# comp_type        0
# comp_size        0
# eco_activity    89
# qualif           0
# region           0
# city             0
# benefits         0
# contract         0
# positions        0
# job_post_id      0
# exper            0
# gender           0
# dtype: int64

# %%
Jadarat_data['eco_activity'].replace(np.nan, 'غير معروف', inplace=True)
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/1345075002.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Jadarat_data['eco_activity'].replace(np.nan, 'غير معروف', inplace=True)
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/1345075002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
Jadarat_data.isnull().sum()
# Out:
# job_title       0
# job_date        0
# comp_name       0
# comp_no         0
# comp_type       0
# comp_size       0
# eco_activity    0
# qualif          0
# region          0
# city            0
# benefits        0
# contract        0
# positions       0
# job_post_id     0
# exper           0
# gender          0
# dtype: int64

# %%
Jadarat_data.loc[200 ,'benefits']
# Out:
# "['Salary', '5500.0', 'Benefits', 'بدل مواصلات 500']"

# %%
# extracts the salary values from the benefits column and stores them in a new column named Salary.
import ast
import numpy as np

def extract_salary(benefits):
    try:
        benefits_list = ast.literal_eval(benefits) 
        for i in range(len(benefits_list) - 1):
            if "salary" in str(benefits_list[i]).lower():
                salary_value = benefits_list[i + 1]
                

                if isinstance(salary_value, (int, float)):  
                    return float(salary_value)
                elif isinstance(salary_value, str) and salary_value.replace('.', '', 1).isdigit():
                    return float(salary_value)

    except Exception as e:
        print(f"Error parsing: {benefits} -> {e}")
        return np.nan  

Jadarat_data["Salary"] =Jadarat_data["benefits"].apply(extract_salary)


print(Jadarat_data[["benefits", "Salary"]].head(10))
# Out:
#                 benefits   Salary
# 0   ['Salary', '5000.0']   5000.0
# 1   ['Salary', '5000.0']   5000.0
# 2   ['Salary', '4000.0']   4000.0
# 3   ['Salary', '5000.0']   5000.0
# 4   ['Salary', '5000.0']   5000.0
# 5   ['Salary', '4500.0']   4500.0
# 6   ['Salary', '6000.0']   6000.0
# 7   ['Salary', '8000.0']   8000.0
# 8  ['Salary', '10000.0']  10000.0
# 9   ['Salary', '5000.0']   5000.0
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/1233279057.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jadarat_data["Salary"] =Jadarat_data["benefits"].apply(extract_salary)

# %%
Jadarat_data["Salary"]
# Out:
# 0       5000.0
# 1       5000.0
# 2       4000.0
# 3       5000.0
# 4       5000.0
#          ...
# 1464    4000.0
# 1465    5500.0
# 1466    4000.0
# 1467    7000.0
# 1468    4000.0
# Name: Salary, Length: 1469, dtype: float64

# %%
Jadarat_data.dtypes
# Out:
# job_title        object
# job_date         object
# comp_name        object
# comp_no          object
# comp_type        object
# comp_size        object
# eco_activity     object
# qualif           object
# region           object
# city             object
# benefits         object
# contract         object
# positions        object
# job_post_id       int64
# exper            object
# gender           object
# Salary          float64
# dtype: object

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
#clean the city coulmn
Jadarat_data.loc[20 ,'city']
# Out:
# 'AR RIYADH...'

# %%
Jadarat_data['city'] = Jadarat_data['city'].str.rstrip('.').str.strip()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/3150642897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jadarat_data['city'] = Jadarat_data['city'].str.rstrip('.').str.strip()

# %%
Jadarat_data.loc[30 ,'city']
# Out:
# 'AR RIYADH'

# %%
Jadarat_data.head(2)
# Out:
#   job_title    job_date                     comp_name    comp_no comp_type  \
# 0     محاسب  27/05/1444      شركة مقر العالم للسفريات   1-317262       خاص
# 1      بائع  27/05/1444  شركة عالم الكهرباء للمقاولات  4-1324428       خاص
#
#       comp_size                                       eco_activity  \
# 0  متوسطة فئة أ                        أنشطة وكالات السياحة والسفر
# 1  متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
#
#                                            qualif           region       city  \
# 0  ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض  AR RIYADH
# 1                                       غير معروف  المنطقة الشرقية  AD DAMMAM
#
#                benefits   contract positions     job_post_id    exper gender  \
# 0  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350419  0 Years   both
# 1  ['Salary', '5000.0']  دوام كامل     0 / 3  20202026350389  0 Years   both
#
#    Salary
# 0  5000.0
# 1  5000.0

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ## Answering questions

# %% [markdown]
# ## What proportion of job postings is attributed to each region within the kingdom?

# %%
region_counts = Jadarat_data['region'].value_counts().head(10)

title_ar = get_display(arabic_reshaper.reshape("Proportion of Job Postings by Region"))
xlabel_ar = get_display(arabic_reshaper.reshape("Region (Arabic)"))
ylabel_ar = get_display(arabic_reshaper.reshape("Percentage of Job Postings"))

region_labels = [get_display(arabic_reshaper.reshape(region)) for region in region_counts.index]

plt.figure(figsize=(10, 6))
plt.bar(region_labels, region_counts.values, color="lightblue", edgecolor="black")

plt.xlabel(xlabel_ar, fontsize=12)
plt.ylabel(ylabel_ar, fontsize=12)
plt.title(title_ar, fontsize=14)

plt.xticks(rotation=45, ha="right", fontsize=10) 

plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Is there a gender preference indicated in the job postings?

# %%
#not strong gender preference
gender_counts = Jadarat_data["gender"].value_counts()

plt.figure(figsize=(8, 5))
gender_counts.plot(kind="bar", color=["blue", "pink", "gray"])
plt.title("Gender Preference in Job Postings")
plt.xlabel("Gender Preference")
plt.ylabel("Number of Job Postings")
plt.xticks(rotation=0)  # Keep labels readable
plt.grid(axis="y", linestyle="--", alpha=0.7)


plt.show()

# %%
from ipyvizzu import Chart, Data, Config, DisplayTarget

# Create an ipyvizzu Chart
chart = Chart()


data = Data()
data.add_data_frame(Jadarat_data[["gender"]])


chart.animate(
    data,
    Config(
        {
            "x": "gender",
            "y": "count()",  # Count occurrences
            "geometry": "rectangle",  # Bar chart
            "color": "gender",
        }
    )
)

chart.display = DisplayTarget.MANUAL
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/1146878770.py:8: DeprecationWarning: 'add_data_frame' is deprecated and will be removed in future versions. Use 'add_df' instead - see https://ipyvizzu.vizzuhq.com/0.17/reference/ipyvizzu/animation/#ipyvizzu.animation.Data.add_df
#   data.add_data_frame(Jadarat_data[["gender"]])

# %% [markdown]
# ## What is the expected salary range for fresh graduates?

# %%
fresh_grads_df = Jadarat_data[Jadarat_data["exper"] == "0 Years"].dropna(subset=["Salary"])

# Plot salary distribution
plt.figure(figsize=(10, 5))
sns.histplot(fresh_grads_df["Salary"], bins=20, kde=True, color="blue")

# Labels and title
plt.xlabel("Salary")
plt.ylabel("Number of Job Offers")
plt.title("Salary Distribution for Fresh Graduates")

# Show plot
plt.show()

# %% [markdown]
# ## Are job opportunities predominantly targeted at individuals with experience, or is there room for fresh graduates as well?

# %%
# Count job listings per experience level
experience_counts = Jadarat_data["exper"].value_counts()

# Plot experience distribution
plt.figure(figsize=(10, 5))
sns.barplot(x=experience_counts.index, y=experience_counts.values, palette="coolwarm")

# Labels and title
plt.xlabel("Experience Level")
plt.ylabel("Number of Job Listings")
plt.title("Job Opportunities by Experience Level")
plt.xticks(rotation=45)

# Show plot
plt.show()
# Out:
# /var/folders/0p/gw35_vxx0vg7lky7mxpy0crh0000gn/T/ipykernel_4054/3716088758.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=experience_counts.index, y=experience_counts.values, palette="coolwarm")

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.
