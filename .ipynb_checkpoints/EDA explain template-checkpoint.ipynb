# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
import dtale
import sweetviz as sv
import arabic_reshaper
from bidi.algorithm import get_display

## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %%
# !pip install arabic-reshaper
# Out:
# Collecting arabic-reshaper
#   Using cached arabic_reshaper-3.0.0-py3-none-any.whl.metadata (12 kB)
# Using cached arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: arabic-reshaper
# Successfully installed arabic-reshaper-3.0.0

# %%
# !pip install python-bidi
# Out:
# Collecting python-bidi
#   Downloading python_bidi-0.6.6-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Downloading python_bidi-0.6.6-cp312-cp312-win_amd64.whl (160 kB)
# Installing collected packages: python-bidi
# Successfully installed python-bidi-0.6.6

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
job_posts = pd.read_csv("Data/Jadarat_data.csv")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
job_posts.shape
# Out:
# (1470, 18)

# %%
job_posts_report = dtale.show(job_posts)
job_posts_report
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-8L6R58JJ:40000/dtale/iframe/8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
job_posts[job_posts['job_post_id']==20202026314796]
# Out:
#      job_title    job_date                                           job_desc  \
# 531  مساعد صحي  06/05/1444  ['أداء مهام بسيطة لمساعدة الأطباء والممرضين في...
#
#                                              job_tasks  \
# 531  ['   تحضير المريض للكشف أو المعالجة وتحضير ومن...
#
#                    comp_name     comp_no comp_type    comp_size  \
# 531  مجمع حكماء الدواء الطبي  20-1958406       خاص  صغيرة فئة أ
#
#                eco_activity  \
# 531  المجمعات الطبية العامة
#
#                                                 qualif  region        city  \
# 531  ['Skill data', 'مساعد صحي', 'متوسط', 'Language...  الباحة  AL BAHA...
#
#                                               benefits   contract positions  \
# 531  ['Salary', '4000.0', 'Benefits', 'تأمينات + تأ...  دوام كامل     5 / 4
#
#         job_post_id    exper gender
# 531  20202026314796  0 Years      F

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
job_posts.head()
# Out:
#                    job_title    job_date  \
# 0                      محاسب  27/05/1444
# 1                       بائع  27/05/1444
# 2  أخصائي عمليات موارد بشرية  27/05/1444
# 3            ميكانيكي سيارات  27/05/1444
# 4                      محاسب  27/05/1444
#
#                                             job_desc  \
# 0  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2  ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3  ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
#
#                                            job_tasks  \
# 0  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2  ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3  ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
#
#                       comp_name    comp_no comp_type     comp_size  \
# 0      شركة مقر العالم للسفريات   1-317262       خاص  متوسطة فئة أ
# 1  شركة عالم الكهرباء للمقاولات  4-1324428       خاص  متوسطة فئة ب
# 2               شركه دار السلام   1-155294       خاص  متوسطة فئة أ
# 3       مؤسسة لمكو لغيار الزيوت  8-1925495       خاص   صغيرة فئة ب
# 4  مؤسسة فكرة اليمامة للمقاولات  1-2356639       خاص         كبيرة
#
#                                         eco_activity  \
# 0                        أنشطة وكالات السياحة والسفر
# 1  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
# 2               ترميمات المباني السكنية والغير سكنية
# 3                                                NaN
# 4                   الإنشاءات العامة للمباني السكنية
#
#                                               qualif           region  \
# 0     ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                                NaN  المنطقة الشرقية
# 2           ['Language data', 'الانجليزيه', 'محترف']           الرياض
# 3  ['Skill data', 'صيانة السيارات وتقييم الاعطال'...  المنطقة الشرقية
# 4  ['Skill data', 'تحمل ضغط العمل', 'محترف', 'Lan...           الرياض
#
#            city              benefits   contract positions     job_post_id  \
# 0  AR RIYADH...  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350419
# 1  AD DAMMAM...  ['Salary', '5000.0']  دوام كامل     0 / 3  20202026350389
# 2  ATH THUMA...  ['Salary', '4000.0']  دوام كامل     0 / 2  20202026350347
# 3   AL HUFUF...  ['Salary', '5000.0']  دوام كامل    0 / 10  20202026350219
# 4  AR RIYADH...  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350043
#
#      exper gender
# 0  0 Years   both
# 1  0 Years   both
# 2  2 Years   both
# 3  0 Years      M
# 4  0 Years   both

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# The data is considered reliable since it's sourced from Kaggle 'https://www.kaggle.com/datasets/moayadalkhozayem/job-postings-in-saudi-arabia'
# Also it was collected by "Jadarat" which is the name of Saudi Arabia's Unified National Employment Platform, accessible at "Jadarat.sa."
# This platform aims to connect Saudi job seekers with employment opportunities in both the public and private sectors, streamlining the job search and recruitment process.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
# The data was posted in 2023, but since the time period isn't taken into consideration in any of the questions, sticking with what the business provided is the best choice :)

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
# We are dealing with only one dataset so it's consistent

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
# The sample is relevant because it includes job postings from Saudi Arabia, covering different regions and industries, making it suitable for analyzing the employment landscape.  

# The variables are relevant as the job location, gender preference, salary, and experience requirements, are included which directly align with the problem statement

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
job_posts.columns
# Out:
# Index(['job_title', 'job_date', 'job_desc', 'job_tasks', 'comp_name',
#        'comp_no', 'comp_type', 'comp_size', 'eco_activity', 'qualif', 'region',
#        'city', 'benefits', 'contract', 'positions', 'job_post_id', 'exper',
#        'gender'],
#       dtype='object')

# %%
dups = job_posts[job_posts['job_post_id'].duplicated(keep=False)]
dups_view=dtale.show(dups)
dups.shape
# Out:
# (173, 18)

# %%
dups_view
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-8L6R58JJ:40000/dtale/iframe/6"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
job_posts[(job_posts['job_post_id']==20202026375503)]
# Out:
#               job_title      job_date  \
# 867   أخصائي علاج طبيعي    05/06/1444
# 911   أخصائي علاج طبيعي  Publish date
# 1152  أخصائي علاج طبيعي    05/06/1444
#
#                                                job_desc  \
# 867   ['دراسة وتحليل الحالة المرضية ووضع خطة وبرنامج...
# 911   ['دراسة وتحليل الحالة المرضية ووضع خطة وبرنامج...
# 1152  ['دراسة وتحليل الحالة المرضية ووضع خطة وبرنامج...
#
#                                               job_tasks          comp_name  \
# 867   ['   دراسة وتحليل برنامج المعالجة الطبيعية الم...  مركز رضوى للحجامة
# 911   ['   دراسة وتحليل برنامج المعالجة الطبيعية الم...  مركز رضوى للحجامة
# 1152  ['   دراسة وتحليل برنامج المعالجة الطبيعية الم...  مركز رضوى للحجامة
#
#          comp_no comp_type    comp_size  \
# 867   14-1709089       خاص  صغيرة فئة أ
# 911   14-1709089       خاص  صغيرة فئة أ
# 1152  14-1709089       خاص  صغيرة فئة ب
#
#                                            eco_activity qualif  \
# 867   الخدمات الطبية بالمصحات المتخصصة ومراكز إعادة ...    NaN
# 911   الخدمات الطبية بالمصحات المتخصصة ومراكز إعادة ...    NaN
# 1152  الخدمات الطبية بالمصحات المتخصصة ومراكز إعادة ...    NaN
#
#                region          city              benefits   contract  \
# 867   المدينة المنورة  YANBU AL ...  ['Salary', '5000.0']  دوام كامل
# 911   المدينة المنورة  YANBU AL ...  ['Salary', '5000.0']  دوام كامل
# 1152  المدينة المنورة  YANBU AL ...  ['Salary', '5000.0']  دوام كامل
#
#      positions     job_post_id    exper gender
# 867      0 / 3  20202026375503  0 Years   both
# 911      0 / 3  20202026375503  0 Years   both
# 1152     0 / 3  20202026375503  0 Years   both

# %%
job_posts[(job_posts['job_post_id']==20202026274543)]
# Out:
#       job_title    job_date  \
# 152  سائق سيارة  23/04/1444
# 281  سائق سيارة  23/04/1444
#
#                                               job_desc  \
# 152  ['تولي مهمة قيادة السيارة بغرض القيام بالأعمال...
# 281  ['تولي مهمة قيادة السيارة بغرض القيام بالأعمال...
#
#                                              job_tasks  \
# 152  ['نقل الحالات إلى كافة المواعيد مستشفى , نيابة...
# 281  ['نقل الحالات إلى كافة المواعيد مستشفى , نيابة...
#
#                       comp_name   comp_no comp_type    comp_size  \
# 152  جمعية حماية الاسرة الخيرية  9-191343       خاص  صغيرة فئة ب
# 281  جمعية حماية الاسرة الخيرية  9-191343       خاص  صغيرة فئة ب
#
#                                           eco_activity qualif  region  \
# 152  مؤسسات الرفاه الاجتماعي (تحديد وتوزيع المساعدا...    NaN  الرياض
# 281                                                NaN    NaN  الرياض
#
#              city              benefits   contract positions     job_post_id  \
# 152  AR RIYADH...  ['Salary', '4500.0']  دوام كامل     0 / 1  20202026274543
# 281  AR RIYADH...  ['Salary', '4500.0']  دوام كامل     0 / 1  20202026274543
#
#        exper gender
# 152  2 Years   both
# 281  2 Years   both

# %%
job_posts[(job_posts['job_post_id']==20202026275555)]
# Out:
#     job_title    job_date                                           job_desc  \
# 120      نادل  24/04/1444  ['استقبال العملاء وتزويدهم بقوائم الاطعمة والم...
# 139      نادل  24/04/1444  ['استقبال العملاء وتزويدهم بقوائم الاطعمة والم...
#
#                                              job_tasks  \
# 120  ['   استقبال العملاء وتزويدهم بقوائم الأطعمة و...
# 139  ['   استقبال العملاء وتزويدهم بقوائم الأطعمة و...
#
#                             comp_name    comp_no comp_type    comp_size  \
# 120  مطعم ملعقة الطاهي لتقديم الوجبات  1-1782322       خاص  صغيرة فئة ب
# 139  مطعم ملعقة الطاهي لتقديم الوجبات  1-1782322       خاص  صغيرة فئة ب
#
#                                           eco_activity qualif  region  \
# 120  تشغيل المقاصف والكفتيريات على أساس إمتياز محدد...    NaN  الرياض
# 139  تشغيل المقاصف والكفتيريات على أساس إمتياز محدد...    NaN  الرياض
#
#              city              benefits   contract positions     job_post_id  \
# 120  AR RIYADH...  ['Salary', '4000.0']  دوام كامل     1 / 4  20202026275555
# 139  AR RIYADH...  ['Salary', '4000.0']  دوام كامل     0 / 4  20202026275555
#
#        exper gender
# 120  0 Years      F
# 139  0 Years      F

# %%
job_posts[(job_posts['job_post_id']==20202026334277)]
# Out:
#             job_title    job_date  \
# 630  مساعد طبيب أسنان  14/05/1444
# 693  مساعد طبيب أسنان  14/05/1444
#
#                                               job_desc  \
# 630  ['تحضير المواد السنية وخلط الحشوات ومنأولة طبي...
# 693  ['تحضير المواد السنية وخلط الحشوات ومنأولة طبي...
#
#                                              job_tasks  \
# 630  ['   استقبال المريض واجلاسه على كرسي طب الاسنا...
# 693  ['   استقبال المريض واجلاسه على كرسي طب الاسنا...
#
#                                   comp_name     comp_no comp_type  \
# 630  مجمع أطباء العناية الطبي شركة شخص واحد  13-1982911       خاص
# 693  مجمع أطباء العناية الطبي شركة شخص واحد  13-1982911       خاص
#
#        comp_size            eco_activity  \
# 630  صغيرة فئة ب  المجمعات الطبية العامة
# 693  صغيرة فئة ب                     NaN
#
#                                                 qualif       region  \
# 630  ['Skill data', 'التخصص ', 'متوسط', 'Language d...  مكة المكرمة
# 693  ['Skill data', 'التخصص ', 'متوسط', 'Language d...  مكة المكرمة
#
#              city                                   benefits   contract  \
# 630  MAKKAH AL...  ['Salary', '6000.0', 'Benefits', 'اخري ']  دوام كامل
# 693  MAKKAH AL...  ['Salary', '6000.0', 'Benefits', 'اخري ']  دوام كامل
#
#     positions     job_post_id    exper gender
# 630     0 / 3  20202026334277  0 Years      F
# 693     1 / 3  20202026334277  0 Years      F

# %%
job_posts[(job_posts['comp_name'].duplicated())&(job_posts['eco_activity'].isnull())].shape
# Out:
# (29, 18)

# %%
job_posts[(job_posts['comp_name'].duplicated())&(job_posts['eco_activity'].isnull())]
# Out:
#                          job_title      job_date  \
# 49       أخصائي عمليات موارد بشرية    25/05/1444
# 281                     سائق سيارة    23/04/1444
# 617          بائع مأكولات ومشروبات    30/04/1444
# 693               مساعد طبيب أسنان    14/05/1444
# 759               كاتب موارد بشرية    18/05/1444
# 760                    مدخل بيانات    18/05/1444
# 761                          مترجم    18/05/1444
# 762   مدير موارد بشرية أمن سيبراني    18/05/1444
# 857                   أخصائي تسويق    24/05/1444
# 910              موظف استقبال فندق  Publish date
# 931                          صيدلي    09/06/1444
# 952              موظف استقبال فندق    08/06/1444
# 961                   أخصائي تسويق    07/06/1444
# 1101                         محاسب    09/06/1444
# 1102                         محاسب    09/06/1444
# 1103                         محاسب    09/06/1444
# 1104                          سباك    09/06/1444
# 1105            مهندس معماري داخلي    09/06/1444
# 1106                  مهندس معماري    09/06/1444
# 1135              كاتب موارد بشرية    06/06/1444
# 1147                  موظف استقبال    05/06/1444
# 1154                          بائع    05/06/1444
# 1334                 سكرتير تنفيذي    20/06/1444
# 1381                         محاسب    09/06/1444
# 1388       فني تدفئة وتهوية وتكييف    02/06/1444
# 1399             موظف صندوق محاسبة    29/06/1444
# 1411                 أخصائي قانوني    29/06/1444
# 1467                         صيدلي    18/06/1444
# 1469                         صيدلي    18/06/1444
#
#                                                job_desc  \
# 49    ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 281   ['تولي مهمة قيادة السيارة بغرض القيام بالأعمال...
# 617   ['بيع المأكولات و المشروبات للزبائن، وتوفير ال...
# 693   ['تحضير المواد السنية وخلط الحشوات ومنأولة طبي...
# 759   ['الحفاظ على سجلات الموظفين وتحديثها، وإعداد ا...
# 760   ['مراجعة استمارات البيانات وتدقيقها، وإدخال وت...
# 761   ['دراسة العلوم اللغوية بلغتين على الأقل مثل: ا...
# 762   ['تطوير الخطط والاستراتيجيات و الإرشادات داخل ...
# 857   ['تحديد الأهداف وتطوير السياسات التسويقية للسل...
# 910   ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 931   ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 952   ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 961   ['تحديد الأهداف وتطوير السياسات التسويقية للسل...
# 1101  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1102  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1103  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1104  ['تحديد المواد اللازمة ومواصفاتها وتقدير الكمي...
# 1105  ['تصميم التعديلات الهيكلية والأثاث والتجهيزات ...
# 1106  ['تصميم المباني الجديدة أو الملحقات أو التعديل...
# 1135  ['الحفاظ على سجلات الموظفين وتحديثها، وإعداد ا...
# 1147  ['استقبال الزوار والعملاء وتحديد مطالبهم وتوجي...
# 1154  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 1334  ['تنظيم المواعيد وإعداد المذكرات وإجراء المراس...
# 1381  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1388  ['تركيب معدات التكييف والتدفئة والتهوية وصيانت...
# 1399  ['عد المبالغ المالية المتوافرة في آلة تسجيل ال...
# 1411  ['مساعدة العملاء والمنشآت في مختلف المسائل الق...
# 1467  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 1469  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
#
#                                               job_tasks  \
# 49    ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 281   ['نقل الحالات إلى كافة المواعيد مستشفى , نيابة...
# 617   ['   بيع المأكولات و المشروبات للزبائن.', '  ت...
# 693   ['   استقبال المريض واجلاسه على كرسي طب الاسنا...
# 759   ['   حفظ سجلات الموظفين، وتحديثها، وتسجيل البي...
# 760   ['   مراجعة الاستمارات المتعلقة بالبيانات وترم...
# 761   ['   دراسة أصول وقواعد ومصطلحات اللغة الأم من ...
# 762   ['   إجراء تقييمات احتياجات التعلّم وتحديد الم...
# 857   ['   تحديد الأهداف العامة والفرعية للتسويق وتط...
# 910   ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 931   ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 952   ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 961   ['   تحديد الأهداف العامة والفرعية للتسويق وتط...
# 1101  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1102  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1103  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1104  ['   تحديد المواد اللازمة ومواصفاتها وتقدير كم...
# 1105  ['   وضع التصاميم لمشاريع الإنشاءات الداخلية و...
# 1106  ['   وضع التصاميم لمشاريع الإنشاءات وإدارة فري...
# 1135  ['   حفظ سجلات الموظفين، وتحديثها، وتسجيل البي...
# 1147  ['   استقبال الزوار والعملاء والترحيب بهم وتحد...
# 1154  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 1334  ['   تنظيم مواعيد المدير/الرئيس وتذكيره بها، و...
# 1381  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1388  ['   المساهمة في مجمل عملية تصميم نظم التهوية ...
# 1399  ['   عدّ المبالغ المالية وتسجيلها في آلة تسجيل...
# 1411  ['   تأهيل الطلبات وتقييم الخيارات القانونية، ...
# 1467  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 1469  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
#
#                                               comp_name     comp_no comp_type  \
# 49    شركة الصخرة المشرفة والسارية الخضراء للاستشارا...    1-321449       خاص
# 281                          جمعية حماية الاسرة الخيرية    9-191343       خاص
# 617                  مقهى الفصل الخامس لتقديم المشروبات  20-1955938       خاص
# 693              مجمع أطباء العناية الطبي شركة شخص واحد  13-1982911       خاص
# 759             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191       خاص
# 760             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191       خاص
# 761             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191       خاص
# 762             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191       خاص
# 857                             مؤسسة لمكو لغيار الزيوت   8-1925495       خاص
# 910                          فندق صفوة الغفران الفندقية    13-84812       خاص
# 931    صيدليه السوسن الجديده لصاحبها سراج عمر سراج عابد     9-97451       خاص
# 952                                  فندق ظاظا الفندقية   9-2126602       خاص
# 961                     شركة رفا الطبية (شركة شخص واحد)    1-362446       خاص
# 1101                  مؤسسة ساري الليل للمقاولات العامة  19-1951616       خاص
# 1102                        شركة أطياف للخدمات المساندة   1-1948186       خاص
# 1103                 مؤسسة فؤاد منصور فؤاد قطب التجارية    9-184502       خاص
# 1104                        مؤسسة اجواء اريحه للمقاولات     2-36018       خاص
# 1105                مؤسسة زرقاء اليمامة للتطوير العقاري   9-2018500       خاص
# 1106                مؤسسة زرقاء اليمامة للتطوير العقاري   9-2018500       خاص
# 1135  الفلاح الراقي للوحدات السكنية المفروشة لصاحبته...    13-85391       خاص
# 1147                            معهد الجودة بلس للتدريب   9-2088192       خاص
# 1154                     أسواق المسارات الرائعة للتجارة  11-2011773       خاص
# 1334                      مؤسسة الاتقان للتطوير العقاري   9-1682987       خاص
# 1381                       شركة اتقان الصيانة للمقاولات   1-2628313       خاص
# 1388                           مؤسسة جيل طيبة للمقاولات    10-77977       خاص
# 1399                            مغاسل نسيم الفل للملابس  15-1963098       خاص
# 1411  شركة الخبراء المتحدون للمحاماة والاستشارات الق...   1-2334348       خاص
# 1467                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
# 1469                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
#
#          comp_size eco_activity  \
# 49    متوسطة فئة ب          NaN
# 281    صغيرة فئة ب          NaN
# 617   متوسطة فئة أ          NaN
# 693    صغيرة فئة ب          NaN
# 759   متوسطة فئة أ          NaN
# 760   متوسطة فئة أ          NaN
# 761   متوسطة فئة أ          NaN
# 762   متوسطة فئة أ          NaN
# 857    صغيرة فئة ب          NaN
# 910   متوسطة فئة ب          NaN
# 931    صغيرة فئة ب          NaN
# 952    صغيرة فئة أ          NaN
# 961    صغيرة فئة ب          NaN
# 1101   صغيرة فئة ب          NaN
# 1102         كبيرة          NaN
# 1103   صغيرة فئة أ          NaN
# 1104   صغيرة فئة ب          NaN
# 1105   صغيرة فئة أ          NaN
# 1106   صغيرة فئة أ          NaN
# 1135   صغيرة فئة ب          NaN
# 1147   صغيرة فئة أ          NaN
# 1154   صغيرة فئة ب          NaN
# 1334   صغيرة فئة ب          NaN
# 1381  متوسطة فئة ب          NaN
# 1388  متوسطة فئة أ          NaN
# 1399           NaN          NaN
# 1411           NaN          NaN
# 1467   صغيرة فئة ب          NaN
# 1469   صغيرة فئة ب          NaN
#
#                                                  qualif           region  \
# 49                                    ['Language data']           الرياض
# 281                                                 NaN           الرياض
# 617            ['Language data', 'الانجليزية', 'مبتدئ']             عسير
# 693   ['Skill data', 'التخصص ', 'متوسط', 'Language d...      مكة المكرمة
# 759                                                 NaN           الرياض
# 760                                                 NaN           الرياض
# 761                                                 NaN           الرياض
# 762                                                 NaN           الرياض
# 857   ['Skill data', 'التسويق', 'محترف', 'Language d...  المنطقة الشرقية
# 910            ['Language data', 'الانجليزية', 'متوسط']      مكة المكرمة
# 931   ['Skill data', 'التواصل', 'متوسط', 'الاتصال', ...      مكة المكرمة
# 952                                                 NaN      مكة المكرمة
# 961   ['Skill data', 'خبرة سابقة في التسويق الطبي', ...           الرياض
# 1101                                                NaN  المنطقة الشرقية
# 1102                                                NaN           الرياض
# 1103                    ['Skill data', 'Language data']      مكة المكرمة
# 1104  ['Skill data', 'Language data', 'Professional ...           القصيم
# 1105                                                NaN      مكة المكرمة
# 1106                                                NaN      مكة المكرمة
# 1135                                                NaN      مكة المكرمة
# 1147  ['Skill data', 'مهارات التسويق - ', 'متوسط', '...      مكة المكرمة
# 1154                                                NaN             عسير
# 1334  ['Skill data', 'متقن', 'متوسط', 'Language data...      مكة المكرمة
# 1381  ['Skill data', 'خبره في الضريبة', 'محترف', 'Pr...           الرياض
# 1388  ['Professional certificate \\ License data', '...  المدينة المنورة
# 1399                                                NaN           الرياض
# 1411  ['Skill data', 'إدارة وتنظيم المستندات والوثائ...           الرياض
# 1467  ['Professional certificate \\ License data', '...           الرياض
# 1469  ['Professional certificate \\ License data', '...           الرياض
#
#               city                                           benefits  \
# 49    AR RIYADH...                               ['Salary', '5000.0']
# 281   AR RIYADH...                               ['Salary', '4500.0']
# 617     TANUMAH...                               ['Salary', '4500.0']
# 693   MAKKAH AL...          ['Salary', '6000.0', 'Benefits', 'اخري ']
# 759   AR RIYADH...                               ['Salary', '4000.0']
# 760   AR RIYADH...                               ['Salary', '4000.0']
# 761   AR RIYADH...                               ['Salary', '4000.0']
# 762   AR RIYADH...                               ['Salary', '5500.0']
# 857    AL HUFUF...                               ['Salary', '7000.0']
# 910   MAKKAH AL...                               ['Salary', '4000.0']
# 931      JEDDAH...           ['Salary', '7500.0', 'Benefits', '1500']
# 952   ABU MARAG...                               ['Salary', '4082.0']
# 961   AR RIYADH...                               ['Salary', '5500.0']
# 1101  HAFAR AL ...                               ['Salary', '4000.0']
# 1102  AR RIYADH...                               ['Salary', '6000.0']
# 1103     JEDDAH...  ['Salary', '6000.0', 'Benefits', '4500 ريال را...
# 1104    AL HAZM...        ['Salary', '3500.0', 'Benefits', 'لا يوجد']
# 1105     JEDDAH...          ['Salary', '8000.0', 'Benefits', 'حوافز']
# 1106     JEDDAH...          ['Salary', '7000.0', 'Benefits', 'حوافز']
# 1135  MAKKAH AL...                               ['Salary', '3200.0']
# 1147     JEDDAH...                               ['Salary', '4000.0']
# 1154    MUHAYIL...   ['Salary', '3000.0', 'Benefits', 'عمولة مبيعات']
# 1334     JEDDAH...   ['Salary', '4000.0', 'Benefits', 'حسب المقابة ']
# 1381  AR RIYADH...  ['Salary', '6000.0', 'Benefits', 'الراتب تقريب...
# 1388  AL MADINA...                               ['Salary', '4000.0']
# 1399  AL KHUBAR...                               ['Salary', '4000.0']
# 1411  AR RIYADH...                               ['Salary', '4000.0']
# 1467  AR RIYADH...                               ['Salary', '7000.0']
# 1469  AR RIYADH...                               ['Salary', '7000.0']
#
#        contract positions     job_post_id    exper gender
# 49    دوام كامل     0 / 1  20202026346827  0 Years      F
# 281   دوام كامل     0 / 1  20202026274543  2 Years   both
# 617   دوام كامل     0 / 2  20202026310433  0 Years      M
# 693   دوام كامل     1 / 3  20202026334277  0 Years      F
# 759   دوام كامل     0 / 1  20202026338147  0 Years      M
# 760   دوام كامل     0 / 1  20202026338137  0 Years      F
# 761   دوام كامل     0 / 1  20202026338132  0 Years      F
# 762   دوام كامل     0 / 1  20202026338127  2 Years      M
# 857   دوام كامل     0 / 1  20202026345923  4 Years   both
# 910   دوام كامل     0 / 3  20202026375557  0 Years      M
# 931   دوام كامل     0 / 2  20202026390776  0 Years      F
# 952   دوام كامل     0 / 1  20202026379628  0 Years      M
# 961   دوام كامل     0 / 1  20202026377722  2 Years      F
# 1101  دوام كامل     0 / 1  20202026391571  0 Years      F
# 1102  دوام كامل     0 / 1  20202026391554  0 Years      F
# 1103  دوام كامل     0 / 1  20202026391499  4 Years      M
# 1104  دوام كامل     0 / 1  20202026391456  2 Years      M
# 1105  دوام كامل     0 / 1  20202026391452  2 Years   both
# 1106  دوام كامل     0 / 1  20202026391450  2 Years   both
# 1135  دوام كامل     0 / 1  20202026377493  0 Years   both
# 1147  دوام كامل     0 / 3  20202026375986  0 Years   both
# 1154  دوام كامل     0 / 2  20202026374445  0 Years   both
# 1334  دوام كامل     0 / 2  20202026400869  0 Years   both
# 1381  دوام كامل     1 / 1  20202026391036  2 Years   both
# 1388  دوام كامل     0 / 1  20202026368859  2 Years      M
# 1399  دوام كامل     0 / 2  20202026407112  0 Years   both
# 1411  دوام كامل     0 / 2  20202026406840  0 Years   both
# 1467  دوام كامل     0 / 1  20202026399061  0 Years   both
# 1469  دوام كامل     0 / 1  20202026399061  0 Years   both

# %%
# According to Jadarat policy, the Job post ID can't be duplicated for different jobs, but yet there are duplicates in the dataset
# After checking some of the duplicated rows I assume that it's usually the same job post but with some updates done

# %%
# After more understanding I noticed that only the 'positions' values change each time and the first one shows the last update

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
job_posts.isnull().sum()
# Out:
# job_title         0
# job_date          0
# job_desc          0
# job_tasks         0
# comp_name         0
# comp_no           0
# comp_type         0
# comp_size        14
# eco_activity     90
# qualif          690
# region            0
# city              0
# benefits          0
# contract          0
# positions         0
# job_post_id       0
# exper             0
# gender            0
# dtype: int64

# %%
# After cleaning them

# %%
job_posts.isnull().sum()
# Out:
# job_title         0
# job_date          0
# job_desc          0
# job_tasks         0
# comp_name         0
# comp_no           0
# comp_type         0
# comp_size        14
# eco_activity     90
# qualif          690
# region            0
# city              0
# benefits          0
# contract          0
# positions         0
# job_post_id       0
# exper             0
# gender            0
# dtype: int64

# %%
job_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     1470 non-null   object
#  1   job_date      1470 non-null   object
#  2   job_desc      1470 non-null   object
#  3   job_tasks     1470 non-null   object
#  4   comp_name     1470 non-null   object
#  5   comp_no       1470 non-null   object
#  6   comp_type     1470 non-null   object
#  7   comp_size     1456 non-null   object
#  8   eco_activity  1380 non-null   object
#  9   qualif        780 non-null    object
#  10  region        1470 non-null   object
#  11  city          1470 non-null   object
#  12  benefits      1470 non-null   object
#  13  contract      1470 non-null   object
#  14  positions     1470 non-null   object
#  15  job_post_id   1470 non-null   int64
#  16  exper         1470 non-null   object
#  17  gender        1470 non-null   object
# dtypes: int64(1), object(17)
# memory usage: 206.8+ KB

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
job_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     1470 non-null   object
#  1   job_date      1470 non-null   object
#  2   job_desc      1470 non-null   object
#  3   job_tasks     1470 non-null   object
#  4   comp_name     1470 non-null   object
#  5   comp_no       1470 non-null   object
#  6   comp_type     1470 non-null   object
#  7   comp_size     1456 non-null   object
#  8   eco_activity  1380 non-null   object
#  9   qualif        780 non-null    object
#  10  region        1470 non-null   object
#  11  city          1470 non-null   object
#  12  benefits      1470 non-null   object
#  13  contract      1470 non-null   object
#  14  positions     1470 non-null   object
#  15  job_post_id   1470 non-null   int64
#  16  exper         1470 non-null   object
#  17  gender        1470 non-null   object
# dtypes: int64(1), object(17)
# memory usage: 206.8+ KB

# %%
# I think that I need to change the type of these columns job_date, comp_no, contract, positions, exper

# %%
job_posts.head(2)
# Out:
#   job_title    job_date                                           job_desc  \
# 0     محاسب  27/05/1444  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1      بائع  27/05/1444  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
#
#                                            job_tasks  \
# 0  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
#
#                       comp_name    comp_no comp_type     comp_size  \
# 0      شركة مقر العالم للسفريات   1-317262       خاص  متوسطة فئة أ
# 1  شركة عالم الكهرباء للمقاولات  4-1324428       خاص  متوسطة فئة ب
#
#                                         eco_activity  \
# 0                        أنشطة وكالات السياحة والسفر
# 1  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
#
#                                            qualif           region  \
# 0  ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                             NaN  المنطقة الشرقية
#
#            city              benefits   contract positions     job_post_id  \
# 0  AR RIYADH...  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350419
# 1  AD DAMMAM...  ['Salary', '5000.0']  دوام كامل     0 / 3  20202026350389
#
#      exper gender
# 0  0 Years   both
# 1  0 Years   both

# %%
# After Cleaning

# %%
job_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     1470 non-null   object
#  1   job_date      1470 non-null   object
#  2   job_desc      1470 non-null   object
#  3   job_tasks     1470 non-null   object
#  4   comp_name     1470 non-null   object
#  5   comp_no       1470 non-null   object
#  6   comp_type     1470 non-null   object
#  7   comp_size     1456 non-null   object
#  8   eco_activity  1380 non-null   object
#  9   qualif        780 non-null    object
#  10  region        1470 non-null   object
#  11  city          1470 non-null   object
#  12  benefits      1470 non-null   object
#  13  contract      1470 non-null   object
#  14  positions     1470 non-null   object
#  15  job_post_id   1470 non-null   int64
#  16  exper         1470 non-null   object
#  17  gender        1470 non-null   object
# dtypes: int64(1), object(17)
# memory usage: 206.8+ KB

# %%
# go to clean them

# %%
# check outliers

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %% [markdown]
# ##### Removing The Duplicated Post ID
# After confirming with the QS on Jadarat.sa website they mentioned that post ID cant be duplicated

# %%
job_posts["job_post_id"].duplicated().sum()
# Out:
# 89

# %%
job_posts.shape
# Out:
# (1470, 18)

# %%
# After understanding the data I saw that the rows duplicating are the same but it has updates on the positions column
job_posts = job_posts.drop_duplicates(subset='job_post_id', keep='first')

# %%
job_posts.shape
# Out:
# (1381, 18)

# %%
job_posts.columns
# Out:
# Index(['job_title', 'job_date', 'job_desc', 'job_tasks', 'comp_name',
#        'comp_no', 'comp_type', 'comp_size', 'eco_activity', 'qualif', 'region',
#        'city', 'benefits', 'contract', 'positions', 'job_post_id', 'exper',
#        'gender'],
#       dtype='object')

# %% [markdown]
# ##### Dealing With the Missing Values

# %%
# Dealing with the missing Values in qualif column
job_posts['qualif'].isnull().sum()
# Out:
# 649

# %%
job_posts['qualif'] = job_posts['qualif'].fillna('Qualification Not Specefied')

# %%
# No missing values but there are values that don't represent a date which was 'Publish date'
job_posts['job_date'].isnull().sum()
# Out:
# 0

# %%
job_posts[(job_posts['job_date'] == 'Publish date')].shape
# Out:
# (38, 18)

# %%
job_posts['job_date'] = job_posts['job_date'].replace('Publish date', '00/00/0000')

# %%
job_posts['comp_size'].isnull().sum()
# Out:
# 14

# %%
job_posts['comp_size'] = job_posts['comp_size'].fillna('غير محدد')

# %%
job_posts['eco_activity'].isnull().sum()
# Out:
# 72

# %%
job_posts['eco_activity'] = job_posts['eco_activity'].fillna('النشاط غير محدد')

# %%
job_posts.isnull().sum()
# Out:
# job_title       0
# job_date        0
# job_desc        0
# job_tasks       0
# comp_name       0
# comp_no         0
# comp_type       0
# comp_size       0
# eco_activity    0
# qualif          0
# region          0
# city            0
# benefits        0
# contract        0
# positions       0
# job_post_id     0
# exper           0
# gender          0
# dtype: int64

# %%
job_posts_report = dtale.show(job_posts)
job_posts_report
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-8L6R58JJ:40000/dtale/iframe/7"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# go back to 6th dimention --> Completeness

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %% [markdown]
# ##### Cities Naming

# %%
# The cities had '...' at the end of the names so I deleted them 
job_posts['city'] = job_posts['city'].str.replace('...', '', regex=False)

# %%
job_posts['city']
# Out:
# 0       AR RIYADH
# 1       AD DAMMAM
# 2       ATH THUMA
# 3        AL HUFUF
# 4       AR RIYADH
#           ...
# 1463    MAKKAH AL
# 1464     AL HUFUF
# 1465    AR RIYADH
# 1466       JEDDAH
# 1468    AL KHUBAR
# Name: city, Length: 1381, dtype: object

# %%
# The date column can't be changed because the hijri date isn't supported

# %%
job_posts.columns
# Out:
# Index(['job_title', 'job_date', 'job_desc', 'job_tasks', 'comp_name',
#        'comp_no', 'comp_type', 'comp_size', 'eco_activity', 'qualif', 'region',
#        'city', 'benefits', 'contract', 'positions', 'job_post_id', 'exper',
#        'gender'],
#       dtype='object')

# %% [markdown]
# ##### Exper Column

# %%
def extract_years(experience_str):
    return int(experience_str.split()[0])


job_posts['exper'] = job_posts['exper'].apply(extract_years)

job_posts.rename(columns={'exper': 'experience_years'}, inplace=True)

# %%
job_posts.head(2)
# Out:
#   job_title    job_date                                           job_desc  \
# 0     محاسب  27/05/1444  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1      بائع  27/05/1444  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
#
#                                            job_tasks  \
# 0  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
#
#                       comp_name    comp_no comp_type     comp_size  \
# 0      شركة مقر العالم للسفريات   1-317262       خاص  متوسطة فئة أ
# 1  شركة عالم الكهرباء للمقاولات  4-1324428       خاص  متوسطة فئة ب
#
#                                         eco_activity  \
# 0                        أنشطة وكالات السياحة والسفر
# 1  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
#
#                                            qualif           region       city  \
# 0  ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض  AR RIYADH
# 1                     Qualification Not Specefied  المنطقة الشرقية  AD DAMMAM
#
#                benefits   contract positions     job_post_id  \
# 0  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350419
# 1  ['Salary', '5000.0']  دوام كامل     0 / 3  20202026350389
#
#    experience_years gender
# 0                 0   both
# 1                 0   both

# %%
job_posts['experience_years'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ##### Positions Column

# %%
# This column means how many are available positions and how many positions

# %%
def extract_positions(position_str):
    available, total = map(int, position_str.split('/'))
    return available, total

job_posts[['available_positions', 'total_positions']] = job_posts['positions'].apply(lambda x: pd.Series(extract_positions(x)))

# %%
job_posts.head(2)
# Out:
#   job_title    job_date                                           job_desc  \
# 0     محاسب  27/05/1444  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1      بائع  27/05/1444  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
#
#                                            job_tasks  \
# 0  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
#
#                       comp_name    comp_no comp_type     comp_size  \
# 0      شركة مقر العالم للسفريات   1-317262       خاص  متوسطة فئة أ
# 1  شركة عالم الكهرباء للمقاولات  4-1324428       خاص  متوسطة فئة ب
#
#                                         eco_activity  \
# 0                        أنشطة وكالات السياحة والسفر
# 1  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
#
#                                            qualif           region       city  \
# 0  ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض  AR RIYADH
# 1                     Qualification Not Specefied  المنطقة الشرقية  AD DAMMAM
#
#                benefits   contract positions     job_post_id  \
# 0  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350419
# 1  ['Salary', '5000.0']  دوام كامل     0 / 3  20202026350389
#
#    experience_years gender  available_positions  total_positions
# 0                 0   both                    0                1
# 1                 0   both                    0                3

# %%
# I also checked the website and the data and understood that the values on the left are the available positions currently 
# And the ones on the right are the total positions that were announced at the first 
# So values in the available positions are more than the ones in total positions doesn't make sense

# %%
def find_invalid_positions(df):
    return df[df['available_positions'] > df['total_positions']].index.tolist()


invalid_indices = find_invalid_positions(job_posts)
print("Invalid row indices:", invalid_indices)
# Out:
# Invalid row indices: [531]

# %%
job_posts.loc[invalid_indices]
# Out:
#      job_title    job_date                                           job_desc  \
# 531  مساعد صحي  06/05/1444  ['أداء مهام بسيطة لمساعدة الأطباء والممرضين في...
#
#                                              job_tasks  \
# 531  ['   تحضير المريض للكشف أو المعالجة وتحضير ومن...
#
#                    comp_name     comp_no comp_type    comp_size  \
# 531  مجمع حكماء الدواء الطبي  20-1958406       خاص  صغيرة فئة أ
#
#                eco_activity  \
# 531  المجمعات الطبية العامة
#
#                                                 qualif  region     city  \
# 531  ['Skill data', 'مساعد صحي', 'متوسط', 'Language...  الباحة  AL BAHA
#
#                                               benefits   contract positions  \
# 531  ['Salary', '4000.0', 'Benefits', 'تأمينات + تأ...  دوام كامل     5 / 4
#
#         job_post_id  experience_years gender  available_positions  \
# 531  20202026314796                 0      F                    5
#
#      total_positions
# 531                4

# %%
def fix_invalid_positions(df):
    mask = df['available_positions'] > df['total_positions']
    df.loc[mask, 'available_positions'] -= 1


fix_invalid_positions(job_posts)

# %%
job_posts.loc[invalid_indices]
# Out:
#      job_title    job_date                                           job_desc  \
# 531  مساعد صحي  06/05/1444  ['أداء مهام بسيطة لمساعدة الأطباء والممرضين في...
#
#                                              job_tasks  \
# 531  ['   تحضير المريض للكشف أو المعالجة وتحضير ومن...
#
#                    comp_name     comp_no comp_type    comp_size  \
# 531  مجمع حكماء الدواء الطبي  20-1958406       خاص  صغيرة فئة أ
#
#                eco_activity  \
# 531  المجمعات الطبية العامة
#
#                                                 qualif  region     city  \
# 531  ['Skill data', 'مساعد صحي', 'متوسط', 'Language...  الباحة  AL BAHA
#
#                                               benefits   contract positions  \
# 531  ['Salary', '4000.0', 'Benefits', 'تأمينات + تأ...  دوام كامل     5 / 4
#
#         job_post_id  experience_years gender  available_positions  \
# 531  20202026314796                 0      F                    4
#
#      total_positions
# 531                4

# %% [markdown]
# ##### Adding Salary Column

# %%
def extract_salary(benefits_str):
    parts = benefits_str.split("'")  
    
    if len(parts) >= 5 and parts[3].replace('.', '', 1).isdigit():  
        return float(parts[3])  
    
    return 0 


job_posts['salary'] = job_posts['benefits'].apply(extract_salary)

# %%
job_posts['benefits'][0].split("'")
# Out:
# ['[', 'Salary', ', ', '5000.0', ']']

# %%
job_posts.head(2)
# Out:
#   job_title    job_date                                           job_desc  \
# 0     محاسب  27/05/1444  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1      بائع  27/05/1444  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
#
#                                            job_tasks  \
# 0  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
#
#                       comp_name    comp_no comp_type     comp_size  \
# 0      شركة مقر العالم للسفريات   1-317262       خاص  متوسطة فئة أ
# 1  شركة عالم الكهرباء للمقاولات  4-1324428       خاص  متوسطة فئة ب
#
#                                         eco_activity  \
# 0                        أنشطة وكالات السياحة والسفر
# 1  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
#
#                                            qualif  ...       city  \
# 0  ['Language data', 'اللغة الانجليزية', 'محترف']  ...  AR RIYADH
# 1                     Qualification Not Specefied  ...  AD DAMMAM
#
#                benefits   contract positions     job_post_id  \
# 0  ['Salary', '5000.0']  دوام كامل     0 / 1  20202026350419
# 1  ['Salary', '5000.0']  دوام كامل     0 / 3  20202026350389
#
#    experience_years  gender available_positions  total_positions  salary
# 0                 0    both                   0                1  5000.0
# 1                 0    both                   0                3  5000.0
#
# [2 rows x 21 columns]

# %%
job_posts['salary'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %%
zscore(job_posts['salary'])
job_posts['salary_z_score'] = zscore(job_posts['salary'])

#Filter the DataFrame to remove outliers
filtered_df = job_posts[(job_posts['salary_z_score'] > 4) | (job_posts['salary_z_score'] < -3)]
filtered_df.sort_values(by='salary')
# Out:
#                     job_title    job_date  \
# 170   مهندس نظم تقنية معلومات  22/04/1444
# 174   فني شبكات تقنية معلومات  22/04/1444
# 229                 مدير مكتب  20/04/1444
# 559                مدير تسويق  05/05/1444
# 749               رئيس تنفيذي  19/05/1444
# 841                مهندس مدني  26/05/1444
# 1239             مهندس معماري  15/06/1444
# 947     أخصائي استشارات أعمال  08/06/1444
# 171              مدير برمجيات  22/04/1444
# 1169                 مدير فرع  01/06/1444
# 470   مدير عمليات موارد بشرية  01/04/1444
# 530   مدير عمليات موارد بشرية  06/05/1444
# 888            طيار جناح ثابت  00/00/0000
#
#                                                job_desc  \
# 170   ['متابعة وتقييم عملية جمع المعطيات ومتطلبات نظ...
# 174   ['تقديم الدعم والمساعدة الفنية للموظفين والعمل...
# 229   ['الإشراف المباشرعلى أنشطة إدارة وتخطيط وتنظيم...
# 559   ['المشاركة في وضع الأهداف والسياسات والخطط الت...
# 749   ['المشاركة في وضع الأهداف والخطط الإستراتيجية ...
# 841   [' فهم مبادئ إدارة المشاريع والبرامج ،مهارات ت...
# 1239  ['تصميم المباني الجديدة أو الملحقات أو التعديل...
# 947   ['الشؤون الصحية بوزارة الحرس الوطني تبحث عن اخ...
# 171   ['المشاركة في تخطيط استراتيجية وأنشطة تطوير ال...
# 1169  ['المشاركة في وضع وإعداد أهداف الفرع في ضوء تو...
# 470   ['المشاركة في وضع الأهداف الرئيسية وخطط وبرامج...
# 530   ['المشاركة في وضع الأهداف الرئيسية وخطط وبرامج...
# 888   ['تدقيق بيانات الرحلة وخطة الطيران، وتفقد وتجه...
#
#                                               job_tasks  \
# 170   ['   إجراء الابحاث والدراسات اللازمة لتطوير بي...
# 174   ['   تقديم الدعم والمساعدة الفنية للموظفين وال...
# 229   ['   إدارة وتوجيه عمليات وإجراءات تنسيق اجتماع...
# 559   ['   المشاركة في وضع الأهداف والسياسات والمباد...
# 749   ['   المشاركة في وضع الإستراتيجية العامة وتحقي...
# 841   [' فهم مبادئ إدارة المشاريع والبرامج ،مهارات ت...
# 1239  ['   وضع التصاميم لمشاريع الإنشاءات وإدارة فري...
# 947   ['   تقديم استشارات  لتطوير الأهداف الرئيسيةفي...
# 171   ['   إنشاء برامج تطوير البرامج وفقاً لاستراتيج...
# 1169  ['   المشاركة في وضع وإعداد الخطط والأهداف الخ...
# 470   ['   المشاركة في تطوير الأهداف الرئيسية لإدارة...
# 530   ['   المشاركة في تطوير الأهداف الرئيسية لإدارة...
# 888   ['   دراسة بيانات الرحلة ومخططها والتحقق من ال...
#
#                                               comp_name     comp_no  \
# 170   شركه العرض المتقن للخدمات التجارية شركة مساهمة...    1-169123
# 174   شركه العرض المتقن للخدمات التجارية شركة مساهمة...    1-169123
# 229   مكتب محمد طه عبدالقادر السقاف للاستشارات الهندسية  13-2004606
# 559     شركة روافد الحقول للوجبات السريعة شركة شخص واحد   9-2075281
# 749                 مؤسسة لحظات القهوة لتقديم المشروبات  13-1978270
# 841                     مكتب مدارات للاستشارات الهندسية   3-1971776
# 1239  شركة المساحون العرب نصر أحمد اسحاق الحسيني للا...    1-155268
# 947                 برنامج مستشفى الملك فهدللحرس الوطني    EST-1237
# 171   شركه العرض المتقن للخدمات التجارية شركة مساهمة...    1-169123
# 1169                          شركة إختبار التربة للقياس   4-1980732
# 470                            شركة ال جي شاكر المحدوده    1-180211
# 530                                   شركة انكر اليابان    1-391480
# 888                                     شركة طيران اديل   9-1432020
#
#        comp_type     comp_size  \
# 170          ﺹﺎﺧ         ﺔﻗﻼﻤﻋ
# 174          ﺹﺎﺧ         ﺔﻗﻼﻤﻋ
# 229          ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 559          ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 749          ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 841          ﺹﺎﺧ  ﺏ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 1239         ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 947   ﺔﻴﻣﻮﻜﺣ ﻪﺒﺷ         ﺓﺮﻴﺒﻛ
# 171          ﺹﺎﺧ         ﺔﻗﻼﻤﻋ
# 1169         ﺹﺎﺧ  ﺝ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 470          ﺹﺎﺧ  ﺝ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 530          ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 888          ﺹﺎﺧ         ﺓﺮﻴﺒﻛ
#
#                                            eco_activity  \
# 170               التسجيل لتقديم خدمات الحوسبة السحابية
# 174               التسجيل لتقديم خدمات الحوسبة السحابية
# 229                  الاستشارات الهندسية للتخطيط الحضري
# 559                                   المطاعم مع الخدمة
# 749                محلات تقديم المشروبات ( الكوفي شوب )
# 841                            إدارة المشاريع الانشائية
# 1239                       إستشارات الهندسة الالكترونية
# 947                                     النشاط غير محدد
# 171               التسجيل لتقديم خدمات الحوسبة السحابية
# 1169                       مختبرات التشييد ومواد البناء
# 470    صناعة أجهزة تكييف الهواء (وحدات أو مركزي ) فريون
# 530   خدمات المكاتب العلمية والفنية للمنتجات عدا الم...
# 888                  النقل الجوي للبضائع المحدد بمواعيد
#
#                                                  qualif  ...  \
# 170                         Qualification Not Specefied  ...
# 174            ['Language data', 'الانجليزية', 'محترف']  ...
# 229   ['Language data', 'العربية', 'محترف', 'الانجلي...  ...
# 559                         Qualification Not Specefied  ...
# 749   ['Skill data', 'تطوير نشاط المؤسسة', 'محترف', ...  ...
# 841                         Qualification Not Specefied  ...
# 1239  ['Skill data', 'التصميم', 'متوسط', 'Language d...  ...
# 947     ['Language data', 'اللغة الإنجليزية ', 'محترف']  ...
# 171                         Qualification Not Specefied  ...
# 1169            ['Language data', 'الانجليزي', 'محترف']  ...
# 470   ['Language data', 'انجليزية', 'محترف', 'Profes...  ...
# 530   ['Language data', 'الانجليزية', 'محترف', 'Prof...  ...
# 888   ['Language data', 'الانجليزي ', 'محترف', 'Prof...  ...
#
#                                                benefits   contract positions  \
# 170                               ['Salary', '15000.0']  دوام كامل     0 / 1
# 174                               ['Salary', '15000.0']  دوام كامل     0 / 1
# 229                               ['Salary', '15000.0']  دوام كامل     0 / 1
# 559                               ['Salary', '15000.0']  دوام كامل     0 / 1
# 749                               ['Salary', '15000.0']  دوام كامل     0 / 1
# 841                               ['Salary', '15000.0']  دوام كامل     0 / 1
# 1239   ['Salary', '15000.0', 'Benefits', 'بدل انتقال ']  دوام كامل     0 / 1
# 947                               ['Salary', '15532.0']  دوام كامل     0 / 1
# 171                               ['Salary', '16000.0']  دوام كامل     0 / 1
# 1169                              ['Salary', '18000.0']  دوام كامل     0 / 4
# 470                               ['Salary', '27000.0']  دوام كامل     0 / 1
# 530   ['Salary', '32000.0', 'Benefits', 'حافز سنوي (...  دوام كامل     0 / 1
# 888                               ['Salary', '35000.0']  دوام كامل    0 / 50
#
#          job_post_id experience_years  gender  available_positions  \
# 170   20202026273632                7    both                    0
# 174   20202026273598                7    both                    0
# 229   20202026270424               12    both                    0
# 559   20202026313724                4    both                    0
# 749   20202026338994               10    both                    0
# 841   20202026349401               10       M                    0
# 1239  20202026395337                7    both                    0
# 947   20202026390144               10    both                    0
# 171   20202026273626                4    both                    0
# 1169  20202026355444               10       M                    0
# 470   20202026231523                4    both                    0
# 530   20202026314815                7    both                    0
# 888   20202026377730               10    both                    0
#
#      total_positions   salary  salary_z_score
# 170                1  15000.0        4.412983
# 174                1  15000.0        4.412983
# 229                1  15000.0        4.412983
# 559                1  15000.0        4.412983
# 749                1  15000.0        4.412983
# 841                1  15000.0        4.412983
# 1239               1  15000.0        4.412983
# 947                1  15532.0        4.654982
# 171                1  16000.0        4.867868
# 1169               4  18000.0        5.777638
# 470                1  27000.0        9.871603
# 530                1  32000.0       12.146029
# 888               50  35000.0       13.510684
#
# [13 rows x 22 columns]

# %%
# Plotting the histogram
filtered_salaries = job_posts[job_posts['salary'] <= 15000]

# Plotting the histogram
plt.figure(figsize=(8, 5))
sns.histplot(filtered_salaries['salary'], bins=10, kde=True, color='navy')

# Arabic text for title and labels
title = "توزيع الرواتب"
xlabel = "الراتب"
ylabel = "التكرار"

# Reshape Arabic text for title and labels
reshaped_title = arabic_reshaper.reshape(title)
reshaped_xlabel = arabic_reshaper.reshape(xlabel)
reshaped_ylabel = arabic_reshaper.reshape(ylabel)

# Bidirectional support for Arabic text
bidirectional_title = get_display(reshaped_title)
bidirectional_xlabel = get_display(reshaped_xlabel)
bidirectional_ylabel = get_display(reshaped_ylabel)

# Set titles and labels
plt.title(bidirectional_title, fontsize=16, weight='bold', color='navy')
plt.xlabel(bidirectional_xlabel, fontsize=14)
plt.ylabel(bidirectional_ylabel, fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# I See that it's better to consider what's above 15000 as an outlier because the distribution looks pretty normal after excluding them

# %%
indexs = job_posts[(job_posts['salary_z_score'] > 4) | (job_posts['salary_z_score'] < -3)].sort_values(by='salary').index

job_posts.drop(indexs,inplace=True)

# %%
zscore(job_posts['experience_years'])
job_posts['experience_years_z_score'] = zscore(job_posts['experience_years'])

#Filter the DataFrame to remove outliers
filtered_df = job_posts[(job_posts['experience_years_z_score'] > 3.5) | (job_posts['experience_years'] < -3)]
filtered_df.sort_values(by='experience_years')
# Out:
#                   job_title    job_date  \
# 17        أخصائي إدارة اداء  26/05/1444
# 1171           مهندس معماري  01/06/1444
# 1169               مدير فرع  01/06/1444
# 947   أخصائي استشارات أعمال  08/06/1444
# 888          طيار جناح ثابت  00/00/0000
# 841              مهندس مدني  26/05/1444
# 749             رئيس تنفيذي  19/05/1444
# 1254         فني حساب كميات  17/06/1444
# 578              وكيل مدرسة  04/05/1444
# 506              مدير إداري  28/03/1444
# 442           مهندس كهربائي  05/04/1444
# 429                حارس أمن  06/04/1444
# 558             مدير حسابات  05/05/1444
# 1255             مهندس مدني  17/06/1444
# 458         معلم رياض أطفال  02/04/1444
# 246              مدير إداري  20/04/1444
# 229               مدير مكتب  20/04/1444
#
#                                                job_desc  \
# 17    [' فهم مبادئ الإدارة الإستراتيجية وقياس الأداء...
# 1171  ['تصميم المباني الجديدة أو الملحقات أو التعديل...
# 1169  ['المشاركة في وضع وإعداد أهداف الفرع في ضوء تو...
# 947   ['الشؤون الصحية بوزارة الحرس الوطني تبحث عن اخ...
# 888   ['تدقيق بيانات الرحلة وخطة الطيران، وتفقد وتجه...
# 841   [' فهم مبادئ إدارة المشاريع والبرامج ،مهارات ت...
# 749   ['المشاركة في وضع الأهداف والخطط الإستراتيجية ...
# 1254  ['حساب كميات المواد اللازمة لتنفيذ الأعمال و إ...
# 578   ['المشاركة في عملية إعداد الخطط الدورية والتشغ...
# 506   ['المشاركة في تطوير الأهداف الرئيسية للشؤون ال...
# 442   ['إعداد التصاميم والمخططات الكهربائية لمشاريع ...
# 429   ['القيام بدوريات ومراقبة أماكن العمل لحراسة ال...
# 558   ['المشاركة في تطوير الأهداف الرئيسية وسياسات و...
# 1255  ['دراسة طبوغرافية وجيولوجية الموقع الإنشائي ون...
# 458   ['إعداد خطة تدريس المباحث المختلفة في رياض الأ...
# 246   ['- تخصص هندسة كهربائية او هندسة ميكانيكية.', ...
# 229   ['الإشراف المباشرعلى أنشطة إدارة وتخطيط وتنظيم...
#
#                                               job_tasks  \
# 17    [' فهم مبادئ الإدارة الإستراتيجية وقياس الأداء...
# 1171  ['   وضع التصاميم لمشاريع الإنشاءات وإدارة فري...
# 1169  ['   المشاركة في وضع وإعداد الخطط والأهداف الخ...
# 947   ['   تقديم استشارات  لتطوير الأهداف الرئيسيةفي...
# 888   ['   دراسة بيانات الرحلة ومخططها والتحقق من ال...
# 841   [' فهم مبادئ إدارة المشاريع والبرامج ،مهارات ت...
# 749   ['   المشاركة في وضع الإستراتيجية العامة وتحقي...
# 1254  ['   دراسة المخططات الهندسية للمشروع، و دراسة ...
# 578   ['وكيلة شؤون تعليمية في مدرسة عالمية    متابعة...
# 506   ['   المشاركة في تطوير الأهداف الرئيسية للشؤون...
# 442   ['   إعداد التصاميم والمخططات الكهربائية لمشار...
# 429   ['   مراقبة عمليات الدخول إلى المنشأة ومغادرته...
# 558   ['   المشاركة في تطوير الأهداف الرئيسية لإدارة...
# 1255  ['   دراسة طبوغرافية وجيولوجية الموقع الإنشائي...
# 458   ['   دراسة وتحليل مناهج المباحث والكتب المدرسي...
# 246   [' - تخصص هندسة كهربائية او هندسة ميكانيكية.',...
# 229   ['   إدارة وتوجيه عمليات وإجراءات تنسيق اجتماع...
#
#                                               comp_name     comp_no  \
# 17                      مكتب مدارات للاستشارات الهندسية   3-1971776
# 1171                    شركة متوازي للاستشارات الهندسية  10-2012202
# 1169                          شركة إختبار التربة للقياس   4-1980732
# 947                 برنامج مستشفى الملك فهدللحرس الوطني    EST-1237
# 888                                     شركة طيران اديل   9-1432020
# 841                     مكتب مدارات للاستشارات الهندسية   3-1971776
# 749                 مؤسسة لحظات القهوة لتقديم المشروبات  13-1978270
# 1254  شركة زهير فايز  ومشاركوه للاستشارات المعمارية ...      9-3774
# 578                    شركة مدارس موسوعة العلوم الاهلية    1-383334
# 506   شركة خالد بن عبدالعزيز الملحم وشركاؤه للاستشار...   4-2006145
# 442             مكتب الإبداع الحديث للاستشارات الهندسية   9-2101436
# 429                           مؤسسة الرجل أنيق التجارية  35-1946206
# 558     شركة روافد الحقول للوجبات السريعة شركة شخص واحد   9-2075281
# 1255  شركة زهير فايز  ومشاركوه للاستشارات المعمارية ...      9-3774
# 458           مركز النجوم العالية ضيافة الأطفال الأهلية   4-1977667
# 246                      شركة العمق للاستشارات الهندسية    1-349583
# 229   مكتب محمد طه عبدالقادر السقاف للاستشارات الهندسية  13-2004606
#
#        comp_type     comp_size  \
# 17           ﺹﺎﺧ  ﺏ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 1171         ﺹﺎﺧ   ﺃ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 1169         ﺹﺎﺧ  ﺝ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 947   ﺔﻴﻣﻮﻜﺣ ﻪﺒﺷ         ﺓﺮﻴﺒﻛ
# 888          ﺹﺎﺧ         ﺓﺮﻴﺒﻛ
# 841          ﺹﺎﺧ  ﺏ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 749          ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 1254         ﺹﺎﺧ  ﺝ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 578          ﺹﺎﺧ  ﺃ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 506          ﺹﺎﺧ   ﺃ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 442          ﺹﺎﺧ   ﺃ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 429          ﺹﺎﺧ   ﺃ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 558          ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 1255         ﺹﺎﺧ  ﺝ ﺔﺌﻓ ﺔﻄﺳﻮﺘﻣ
# 458          ﺹﺎﺧ   ﺃ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 246          ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
# 229          ﺹﺎﺧ   ﺏ ﺔﺌﻓ ﺓﺮﻴﻐﺻ
#
#                                            eco_activity  \
# 17                             إدارة المشاريع الانشائية
# 1171              أنشطة الاستشارات في مجال الحاسب الآلي
# 1169                       مختبرات التشييد ومواد البناء
# 947                                     النشاط غير محدد
# 888                  النقل الجوي للبضائع المحدد بمواعيد
# 841                            إدارة المشاريع الانشائية
# 749                محلات تقديم المشروبات ( الكوفي شوب )
# 1254               أنشطة الاستشارات الهندسية والمعمارية
# 578                 التعليم المتوسط للطالبات بمنهج وطني
# 506                أنشطة الاستشارات الهندسية والمعمارية
# 442   تقديم خدمات الاستشارات الهندسية في مجال الوقاي...
# 429             البيع بالتجزئة للملابس الجاهزة الرجالية
# 558                                   المطاعم مع الخدمة
# 1255               أنشطة الاستشارات الهندسية والمعمارية
# 458                         مراكز ضيافة الأطفال الأهلية
# 246                أنشطة الاستشارات الهندسية والمعمارية
# 229                  الاستشارات الهندسية للتخطيط الحضري
#
#                                                  qualif  ...   contract  \
# 17                          Qualification Not Specefied  ...  دوام كامل
# 1171  ['Skill data', 'استقال العملاء', 'محترف', 'معر...  ...  دوام كامل
# 1169            ['Language data', 'الانجليزي', 'محترف']  ...  دوام كامل
# 947     ['Language data', 'اللغة الإنجليزية ', 'محترف']  ...  دوام كامل
# 888   ['Language data', 'الانجليزي ', 'محترف', 'Prof...  ...  دوام كامل
# 841                         Qualification Not Specefied  ...  دوام كامل
# 749   ['Skill data', 'تطوير نشاط المؤسسة', 'محترف', ...  ...  دوام كامل
# 1254  ['Skill data', 'لدية خبرة في مجال مشاريع الإشر...  ...  دوام كامل
# 578   ['Skill data', 'اتقان اللغة الأنجليزية ', 'محت...  ...  دوام كامل
# 506                         Qualification Not Specefied  ...  دوام كامل
# 442                         Qualification Not Specefied  ...  دوام كامل
# 429                         Qualification Not Specefied  ...  دوام كامل
# 558                         Qualification Not Specefied  ...  دوام كامل
# 1255  ['Skill data', 'لدية خبرة في تصميم وإشراف ومتا...  ...  دوام كامل
# 458              ['Skill data', 'لغة إنجليزي', 'متوسط']  ...  دوام كامل
# 246              ['Language data', 'انجليزيه', 'محترف']  ...  دوام كامل
# 229   ['Language data', 'العربية', 'محترف', 'الانجلي...  ...  دوام كامل
#
#      positions     job_post_id experience_years gender  available_positions  \
# 17       0 / 1  20202026349417               10      M                    0
# 1171     0 / 1  20202026354976               10   both                    0
# 1169     0 / 4  20202026355444               10      M                    0
# 947      0 / 1  20202026390144               10   both                    0
# 888     0 / 50  20202026377730               10   both                    0
# 841      0 / 1  20202026349401               10      M                    0
# 749      0 / 1  20202026338994               10   both                    0
# 1254     0 / 1  20202026398094               10      M                    0
# 578      0 / 1  20202026311955               10      F                    0
# 506      0 / 1  20202026207729               10      M                    0
# 442      0 / 1  20202026236481               10   both                    0
# 429      0 / 3  20202026238199               10      M                    0
# 558      0 / 1  20202026313728               10   both                    0
# 1255     0 / 1  20202026398075               10      M                    0
# 458      0 / 1  20202026232615               12      F                    0
# 246      0 / 1  20202026269515               12      M                    0
# 229      0 / 1  20202026270424               12   both                    0
#
#       total_positions   salary  salary_z_score  experience_years_z_score
# 17                  1  12000.0        3.048328                  4.622906
# 1171                1   8000.0        1.228788                  4.622906
# 1169                4  18000.0        5.777638                  4.622906
# 947                 1  15532.0        4.654982                  4.622906
# 888                50  35000.0       13.510684                  4.622906
# 841                 1  15000.0        4.412983                  4.622906
# 749                 1  15000.0        4.412983                  4.622906
# 1254                1   9900.0        2.093069                  4.622906
# 578                 1   8500.0        1.456230                  4.622906
# 506                 1   6000.0        0.319018                  4.622906
# 442                 1   8000.0        1.228788                  4.622906
# 429                 3   4000.0       -0.590752                  4.622906
# 558                 1  10000.0        2.138558                  4.622906
# 1255                1   9900.0        2.093069                  4.622906
# 458                 1   7500.0        1.001345                  5.683850
# 246                 1  10000.0        2.138558                  5.683850
# 229                 1  15000.0        4.412983                  5.683850
#
# [17 rows x 23 columns]

# %%
filtered_years = job_posts[job_posts['experience_years'] <= 7]
# Plotting the histogram
plt.figure(figsize=(8, 5))
sns.histplot(filtered_years['experience_years'], bins=6, kde=True, color='navy')

# Arabic text for title and labels
title = "توزيع سنوات الخبرة"
xlabel = "سنوات الخبرة"
ylabel = "التكرار"

# Reshape Arabic text for title and labels
reshaped_title = arabic_reshaper.reshape(title)
reshaped_xlabel = arabic_reshaper.reshape(xlabel)
reshaped_ylabel = arabic_reshaper.reshape(ylabel)

# Bidirectional support for Arabic text
bidirectional_title = get_display(reshaped_title)
bidirectional_xlabel = get_display(reshaped_xlabel)
bidirectional_ylabel = get_display(reshaped_ylabel)

# Set titles and labels
plt.title(bidirectional_title, fontsize=16, weight='bold', color='navy')
plt.xlabel(bidirectional_xlabel, fontsize=14)
plt.ylabel(bidirectional_ylabel, fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# I See that it's better to consider what's above 7 years as an outlier because the distribution looks pretty normal after excluding them

# %%
indexs = job_posts[(job_posts['experience_years_z_score'] > 3.5) | (job_posts['experience_years'] < -3)].sort_values(by='experience_years').index

job_posts.drop(indexs,inplace=True)

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %%
#job_posts_viz = sv.analyze(job_posts)

#job_posts_viz.show_html("sweetviz_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1588 (\N{ARABIC LETTER SHEEN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Matplotlib currently does not support Arabic natively.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1576 (\N{ARABIC LETTER BEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1607 (\N{ARABIC LETTER HEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1581 (\N{ARABIC LETTER HAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1603 (\N{ARABIC LETTER KAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1610 (\N{ARABIC LETTER YEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1582 (\N{ARABIC LETTER KHAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1589 (\N{ARABIC LETTER SAD}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1588 (\N{ARABIC LETTER SHEEN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Matplotlib currently does not support Arabic natively.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1576 (\N{ARABIC LETTER BEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1607 (\N{ARABIC LETTER HEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1581 (\N{ARABIC LETTER HAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1603 (\N{ARABIC LETTER KAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1610 (\N{ARABIC LETTER YEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1582 (\N{ARABIC LETTER KHAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1589 (\N{ARABIC LETTER SAD}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Matplotlib currently does not support Arabic natively.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1578 (\N{ARABIC LETTER TEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1587 (\N{ARABIC LETTER SEEN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1591 (\N{ARABIC LETTER TAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1601 (\N{ARABIC LETTER FEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1574 (\N{ARABIC LETTER YEH WITH HAMZA ABOVE}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1576 (\N{ARABIC LETTER BEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1571 (\N{ARABIC LETTER ALEF WITH HAMZA ABOVE}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1589 (\N{ARABIC LETTER SAD}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1594 (\N{ARABIC LETTER GHAIN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1610 (\N{ARABIC LETTER YEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1585 (\N{ARABIC LETTER REH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1594 (\N{ARABIC LETTER GHAIN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Matplotlib currently does not support Arabic natively.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1610 (\N{ARABIC LETTER YEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1585 (\N{ARABIC LETTER REH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1581 (\N{ARABIC LETTER HAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1583 (\N{ARABIC LETTER DAL}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1593 (\N{ARABIC LETTER AIN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1604 (\N{ARABIC LETTER LAM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1602 (\N{ARABIC LETTER QAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1578 (\N{ARABIC LETTER TEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1587 (\N{ARABIC LETTER SEEN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1591 (\N{ARABIC LETTER TAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1601 (\N{ARABIC LETTER FEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1574 (\N{ARABIC LETTER YEH WITH HAMZA ABOVE}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1580 (\N{ARABIC LETTER JEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1603 (\N{ARABIC LETTER KAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1576 (\N{ARABIC LETTER BEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1571 (\N{ARABIC LETTER ALEF WITH HAMZA ABOVE}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1589 (\N{ARABIC LETTER SAD}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Matplotlib currently does not support Arabic natively.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1604 (\N{ARABIC LETTER LAM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1583 (\N{ARABIC LETTER DAL}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1610 (\N{ARABIC LETTER YEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1606 (\N{ARABIC LETTER NOON}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1585 (\N{ARABIC LETTER REH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1591 (\N{ARABIC LETTER TAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1602 (\N{ARABIC LETTER QAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1588 (\N{ARABIC LETTER SHEEN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1603 (\N{ARABIC LETTER KAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1590 (\N{ARABIC LETTER DAD}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Matplotlib currently does not support Arabic natively.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1582 (\N{ARABIC LETTER KHAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1585 (\N{ARABIC LETTER REH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1609 (\N{ARABIC LETTER ALEF MAKSURA}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1604 (\N{ARABIC LETTER LAM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1580 (\N{ARABIC LETTER JEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1601 (\N{ARABIC LETTER FEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1581 (\N{ARABIC LETTER HAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1583 (\N{ARABIC LETTER DAL}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1588 (\N{ARABIC LETTER SHEEN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1610 (\N{ARABIC LETTER YEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1586 (\N{ARABIC LETTER ZAIN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1606 (\N{ARABIC LETTER NOON}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1578 (\N{ARABIC LETTER TEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1576 (\N{ARABIC LETTER BEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1603 (\N{ARABIC LETTER KAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1574 (\N{ARABIC LETTER YEH WITH HAMZA ABOVE}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1602 (\N{ARABIC LETTER QAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1589 (\N{ARABIC LETTER SAD}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1593 (\N{ARABIC LETTER AIN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1587 (\N{ARABIC LETTER SEEN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1591 (\N{ARABIC LETTER TAH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1590 (\N{ARABIC LETTER DAD}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1593 (\N{ARABIC LETTER AIN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Matplotlib currently does not support Arabic natively.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1604 (\N{ARABIC LETTER LAM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1606 (\N{ARABIC LETTER NOON}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1576 (\N{ARABIC LETTER BEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1583 (\N{ARABIC LETTER DAL}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1603 (\N{ARABIC LETTER KAF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1593 (\N{ARABIC LETTER AIN}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Matplotlib currently does not support Arabic natively.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1604 (\N{ARABIC LETTER LAM}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1606 (\N{ARABIC LETTER NOON}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1576 (\N{ARABIC LETTER BEH}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1583 (\N{ARABIC LETTER DAL}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) Roboto.
#
# C:\Users\rahaf\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning:
#
# Glyph 1603 (\N{ARABIC LETTER KAF}) missing from font(s) Roboto.
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %%
job_posts.columns
# Out:
# Index(['job_title', 'job_date', 'job_desc', 'job_tasks', 'comp_name',
#        'comp_no', 'comp_type', 'comp_size', 'eco_activity', 'qualif', 'region',
#        'city', 'benefits', 'contract', 'job_post_id', 'experience_years',
#        'gender', 'available_positions', 'total_positions', 'salary'],
#       dtype='object')

# %%
# Set font family to Arial
plt.rcParams["font.family"] = 'Arial' 

# Arabic text for title and labels
title = "توزيع أنواع الشركات"
xlabel = "نوع الشركة"
ylabel = "العدد"

# Reshape Arabic text for title and labels
reshaped_title = arabic_reshaper.reshape(title)
reshaped_xlabel = arabic_reshaper.reshape(xlabel)
reshaped_ylabel = arabic_reshaper.reshape(ylabel)

# Bidirectional support for Arabic text
bidirectional_title = get_display(reshaped_title)
bidirectional_xlabel = get_display(reshaped_xlabel)
bidirectional_ylabel = get_display(reshaped_ylabel)

# Reshape and display x-tick labels (company types) in Arabic
job_posts['comp_type'] = job_posts['comp_type'].apply(lambda x: get_display(arabic_reshaper.reshape(x)))

# Plot
plt.figure(figsize=(8, 5))
sns.countplot(data=job_posts, x='comp_type', color='purple')
plt.title(bidirectional_title)  # Arabic title
plt.xlabel(bidirectional_xlabel)  # Arabic label
plt.ylabel(bidirectional_ylabel)  # Arabic label
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# We can see the HUGE difference between how frequently private companies post job offers in Jadarat.sa 
# Unlike how super rare it is for governmental companies. So if you're looking for a job in a private company, Jadarat.sa will help you

# %%
# Set font family to Arial
plt.rcParams["font.family"] = 'Arial'  # أو أي خط يدعم العربية

# Arabic text for title and labels
title = "توزيع حجم الشركة"
xlabel = "حجم الشركة"
ylabel = "العدد"

# Reshape Arabic text for title and labels
reshaped_title = arabic_reshaper.reshape(title)
reshaped_xlabel = arabic_reshaper.reshape(xlabel)
reshaped_ylabel = arabic_reshaper.reshape(ylabel)

# Bidirectional support for Arabic text
bidirectional_title = get_display(reshaped_title)
bidirectional_xlabel = get_display(reshaped_xlabel)
bidirectional_ylabel = get_display(reshaped_ylabel)

# Reshape and display x-tick labels (company sizes) in Arabic
job_posts['comp_size'] = job_posts['comp_size'].apply(lambda x: get_display(arabic_reshaper.reshape(x)))

# Plot
plt.figure(figsize=(8, 5))
sns.countplot(data=job_posts, x='comp_size', color='pink')
plt.title(bidirectional_title)  # Arabic title
plt.xlabel(bidirectional_xlabel)  # Arabic label
plt.ylabel(bidirectional_ylabel)  # Arabic label
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# The type 'صغيرة فئة ب' has the largest frequency it's almost double the closest value

# %%
# Mapping English gender labels to Arabic
gender_mapping = {
    "M": "ذكر",
    "F": "أنثى",
    "both": "كلا الجنسين"
}

# Replace English labels with Arabic
gender_counts = job_posts['gender'].map(gender_mapping).value_counts()

# Arabic reshaping for labels
reshaped_labels = [get_display(arabic_reshaper.reshape(gender)) for gender in gender_counts.index]

# Plot pie chart
colors = ['#6a0dad', '#b19cd9', '#dda0dd']  # Purple shades
plt.figure(figsize=(7, 7))
plt.pie(gender_counts, labels=reshaped_labels, autopct='%1.1f%%', colors=colors, startangle=140)

# Arabic title
title = "توزيع الوظائف حسب الجنس"
plt.title(get_display(arabic_reshaper.reshape(title)))

# Show the plot
plt.show()

# %%
# We can see clearly that the percentages are almost equally distributed between the jobs that ask for males and the ones that ask for both genders
# The jobs that ask for females only are less by almost 10% than the male ones

# %%
# Get the top 10 job titles
top_10_job_titles = job_posts['job_title'].value_counts().head(10)

# Reshape job titles for Arabic support (if needed)
reshaped_titles = [arabic_reshaper.reshape(title) for title in top_10_job_titles.index]

# Bidirectional support for Arabic text
bidirectional_titles = [get_display(title) for title in reshaped_titles]

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_job_titles.values, y=bidirectional_titles, palette='viridis')
plt.title(get_display(arabic_reshaper.reshape('أعلى 10 عناوين وظائف')))  # Arabic title
plt.xlabel(get_display(arabic_reshaper.reshape('العدد')))  # Arabic label
plt.ylabel(get_display(arabic_reshaper.reshape('عنوان الوظيفة')))  # Arabic label
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\rahaf\AppData\Local\Temp\ipykernel_13100\3493529998.py:12: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
# The marketing and sales departments are highly requested, as we can see
# So we can tell that graduates with related majors to these jobs can look for different opportunities in Jadarat.sa

# %%
job_posts['qualif'].value_counts().head(15)
# Out:
# qualif
# Qualification Not Specefied                                                                                649
# ['Language data', 'الانجليزية', 'متوسط']                                                                    23
# ['Language data', 'الانجليزية', 'محترف']                                                                     9
# ['Language data', 'العربية', 'محترف', 'الانجليزية', 'متوسط']                                                 9
# ['Language data', 'اللغة الانجليزية', 'محترف']                                                               8
# ['Language data', 'اللغة الانجليزية', 'متوسط']                                                               6
# ['Language data', 'انجليزي', 'متوسط']                                                                        6
# ['Language data', 'العربية', 'محترف']                                                                        6
# ['Skill data', 'لدية خبرة في مجال تصميم وإشراف المشاريع', 'محترف', 'Language data', 'إنجليزي', 'محترف']      5
# ['Professional certificate \\ License data', 'اعتماد الهيئة السعودية للمهندسين', 'ضروري']                    5
# ['Language data', 'العربية', 'محترف', 'Professional certificate \\ License data', 'بكالوريوس', 'ضروري']      4
# ['Language data', 'الإنجليزية', 'محترف']                                                                     4
# ['Language data', 'لغة انجليزية', 'متوسط']                                                                   3
# ['Language data', 'لغة انجليزية', 'محترف']                                                                   3
# ['Language data', 'اللغة الانجليزية ', 'متوسط']                                                              3
# Name: count, dtype: int64

# %%
# Top 15 qualifications asked by the employers focused mostly on English, and that shows the importance of learning English

# %%
region_counts = job_posts['region'].value_counts()


# Reshape Arabic text for x-axis labels
reshaped_regions = [arabic_reshaper.reshape(r) for r in region_counts.index]
bidirectional_regions = [get_display(r) for r in reshaped_regions]

# Plotting the bar chart
plt.figure(figsize=(10, 6))
bars = region_counts.plot(kind='bar', color='#7a1e8b')  # Dark purple color for bars

# Arabic text for title and labels
title = "توزيع المناطق"
xlabel = "المناطق"
ylabel = "التكرار"

# Reshape Arabic text and apply bidirectional layout
reshaped_title = arabic_reshaper.reshape(title)
reshaped_xlabel = arabic_reshaper.reshape(xlabel)
reshaped_ylabel = arabic_reshaper.reshape(ylabel)

# Bidirectional support for Arabic text
bidirectional_title = get_display(reshaped_title)
bidirectional_xlabel = get_display(reshaped_xlabel)
bidirectional_ylabel = get_display(reshaped_ylabel)

# Set titles and labels
plt.title(bidirectional_title, fontsize=16, weight='bold', color='#7a1e8b')  # Arabic title
plt.xlabel(bidirectional_xlabel, fontsize=14)  # Arabic label
plt.ylabel(bidirectional_ylabel, fontsize=14)  # Arabic label
plt.xticks(ticks=range(len(bidirectional_regions)), labels=bidirectional_regions, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping of tick-labels
plt.show()

# %%
# The job posts in Riyadh are nearly 600, which is almost 40% of the total of the job posts available in Jadarat.sa

# %%
# Count the occurrences of each contract type
contract_counts = job_posts['contract'].value_counts()

# Reshape Arabic text for labels
reshaped_contracts = [arabic_reshaper.reshape(c) for c in contract_counts.index]
bidirectional_contracts = [get_display(c) for c in reshaped_contracts]

# Plotting the pie chart
plt.figure(figsize=(8, 10))
plt.pie(contract_counts, labels=bidirectional_contracts, autopct='%1.1f%%', startangle=90, colors=['#1f77b4', '#17becf'])

# Arabic text for title
title = "توزيع أنواع العقود"
reshaped_title = arabic_reshaper.reshape(title)
bidirectional_title = get_display(reshaped_title)

# Set title
plt.title(bidirectional_title, fontsize=16, weight='bold', color='navy')

# Show the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# Almost ALL of the jobs are full time jobs

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %%
job_posts.dtypes
# Out:
# job_title               object
# job_date                object
# job_desc                object
# job_tasks               object
# comp_name               object
# comp_no                 object
# comp_type               object
# comp_size               object
# eco_activity            object
# qualif                  object
# region                  object
# city                    object
# benefits                object
# contract                object
# job_post_id              int64
# experience_years         int64
# gender                  object
# available_positions      int64
# total_positions          int64
# salary                 float64
# dtype: object

# %%
# Plotting the histogram
plt.figure(figsize=(8, 5))
sns.histplot(job_posts['experience_years'], bins=8, kde=True, color='navy')

# Arabic text for title and labels
title = "توزيع سنوات الخبرة"
xlabel = "سنوات الخبرة"
ylabel = "التكرار"

# Reshape Arabic text for title and labels
reshaped_title = arabic_reshaper.reshape(title)
reshaped_xlabel = arabic_reshaper.reshape(xlabel)
reshaped_ylabel = arabic_reshaper.reshape(ylabel)

# Bidirectional support for Arabic text
bidirectional_title = get_display(reshaped_title)
bidirectional_xlabel = get_display(reshaped_xlabel)
bidirectional_ylabel = get_display(reshaped_ylabel)

# Set titles and labels
plt.title(bidirectional_title, fontsize=16, weight='bold', color='navy')
plt.xlabel(bidirectional_xlabel, fontsize=14)
plt.ylabel(bidirectional_ylabel, fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# Nearly 50% of the posted jobs looks for fresh graduates or people who don't have a work experience in general

# %%
# Plotting the histogram
plt.figure(figsize=(8, 5))
sns.histplot(job_posts['salary'], bins=10, kde=True, color='navy')

# Arabic text for title and labels
title = "توزيع الرواتب"
xlabel = "الراتب"
ylabel = "التكرار"

# Reshape Arabic text for title and labels
reshaped_title = arabic_reshaper.reshape(title)
reshaped_xlabel = arabic_reshaper.reshape(xlabel)
reshaped_ylabel = arabic_reshaper.reshape(ylabel)

# Bidirectional support for Arabic text
bidirectional_title = get_display(reshaped_title)
bidirectional_xlabel = get_display(reshaped_xlabel)
bidirectional_ylabel = get_display(reshaped_ylabel)

# Set titles and labels
plt.title(bidirectional_title, fontsize=16, weight='bold', color='navy')
plt.xlabel(bidirectional_xlabel, fontsize=14)
plt.ylabel(bidirectional_ylabel, fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# I can see that 80% of the jobs offer salaries between 3000-6000

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %%
job_posts.describe().T
# Out:
#                       count          mean           std           min  \
# job_post_id          1381.0  2.020203e+13  59236.366491  2.020203e+13
# experience_years     1381.0  1.285301e+00      1.885796  0.000000e+00
# available_positions  1381.0  1.593049e-02      0.177849  0.000000e+00
# total_positions      1381.0  2.937726e+00      6.336954  1.000000e+00
# salary               1381.0  5.298685e+03   2199.154008  3.000000e+03
#
#                               25%           50%           75%           max
# job_post_id          2.020203e+13  2.020203e+13  2.020203e+13  2.020203e+13
# experience_years     0.000000e+00  0.000000e+00  2.000000e+00  1.200000e+01
# available_positions  0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# total_positions      1.000000e+00  1.000000e+00  2.000000e+00  5.000000e+01
# salary               4.000000e+03  4.500000e+03  6.000000e+03  3.500000e+04

# %%
 # Salary column:
 # Mean: 5,298.68 and Median: 4,500.
 # The mean is larger than the median, and this means the distribution is positively skewed.
 # Standard Deviation: 2,199.15, showing that there is a high variation in salaries.
 # Range: 3,000 to 35,000.
 # 25% of jobs offer salaries below 4,000, while 75% offer up to 6,000.


# Experience Years column:
 # Mean: 1.29 years and Median: 2 years.
 # The median is larger than the mean, and this means the distribution is negatively skewed.
 # Standard Deviation: 1.88 years, showing high variability.
 # Range: 0 to 12 years.
 # 25% of jobs require 0 years of experience, while 75% require up to 2 years.

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# ### Heatmap

# %%
# Select numeric columns and exclude specific ones (without affecting main DataFrame)
numeric_df = job_posts.select_dtypes(include=[np.number])

# Correlation matrix
corr = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
heatmap = plt.imshow(corr, cmap='coolwarm', interpolation='none')
plt.colorbar(heatmap)

# Set axis labels
plt.xticks(np.arange(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(np.arange(len(corr.columns)), corr.columns)

# Annotate each cell with percentage values
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        plt.text(j, i, f"{corr.iloc[i, j]*100:.1f}%", ha='center', va='center', color='black')

plt.title('Correlation Heatmap (Percentages)')
plt.show()

# %%
# Strongest relationship: Experience Years & Salary (51.1%) is expected, as more experience generally means higher salary.

# %%
job_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1357 entries, 0 to 1468
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   job_title                 1357 non-null   object
#  1   job_date                  1357 non-null   object
#  2   job_desc                  1357 non-null   object
#  3   job_tasks                 1357 non-null   object
#  4   comp_name                 1357 non-null   object
#  5   comp_no                   1357 non-null   object
#  6   comp_type                 1357 non-null   object
#  7   comp_size                 1357 non-null   object
#  8   eco_activity              1357 non-null   object
#  9   qualif                    1357 non-null   object
#  10  region                    1357 non-null   object
#  11  city                      1357 non-null   object
#  12  benefits                  1357 non-null   object
#  13  contract                  1357 non-null   object
#  14  positions                 1357 non-null   object
#  15  job_post_id               1357 non-null   int64
#  16  experience_years          1357 non-null   int64
#  17  gender                    1357 non-null   object
#  18  available_positions       1357 non-null   int64
#  19  total_positions           1357 non-null   int64
#  20  salary                    1357 non-null   float64
#  21  salary_z_score            1357 non-null   float64
#  22  experience_years_z_score  1357 non-null   float64
# dtypes: float64(3), int64(4), object(16)
# memory usage: 254.4+ KB

# %% [markdown]
# # Q1 - What proportion of job postings is attributed to each region within the kingdom?

# %%
# Count job postings per region
region_counts = job_posts['region'].value_counts()
total_jobs = len(job_posts)  # Total job postings

# Calculate percentage
region_percentages = (region_counts / total_jobs) * 100

# Reshape Arabic text for labels
reshaped_labels = [get_display(arabic_reshaper.reshape(region)) for region in region_counts.index]

# Plot bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=region_percentages, y=reshaped_labels, palette="viridis")

# Add percentage labels on bars
for index, value in enumerate(region_percentages):
    plt.text(value + 1, index, f"{value:.1f}%", fontsize=12, color='black', va='center')

# Arabic title and labels
title = "توزيع الوظائف حسب المنطقة"
xlabel = "النسبة المئوية"
ylabel = "المنطقة"

plt.title(get_display(arabic_reshaper.reshape(title)), fontsize=14, fontweight='bold')
plt.xlabel(get_display(arabic_reshaper.reshape(xlabel)), fontsize=12)
plt.ylabel(get_display(arabic_reshaper.reshape(ylabel)), fontsize=12)

# Show the plot
plt.xlim(0, max(region_percentages) + 5)  # Adjust x-axis limit
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\rahaf\AppData\Local\Temp\ipykernel_13100\1644399429.py:13: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [raw]
# This chart shows that the majority of job postings are concentrated in Riyadh (42.7%),
# followed by Makkah (24.8%) and Eastern Province (15.2%), while other regions have significantly fewer job postings.

# %% [markdown]
# # Q2 - Is there a gender preference indicated in the job postings?

# %%
# Mapping English gender labels to Arabic
gender_mapping = {
    "M": "ذكر",
    "F": "أنثى",
    "both": "كلا الجنسين"
}

# Replace English labels with Arabic
gender_counts = job_posts['gender'].map(gender_mapping).value_counts()

# Arabic reshaping for labels
reshaped_labels = [get_display(arabic_reshaper.reshape(gender)) for gender in gender_counts.index]

# Plot pie chart
colors = ['#6a0dad', '#b19cd9', '#dda0dd']  # Purple shades
plt.figure(figsize=(7, 7))
plt.pie(gender_counts, labels=reshaped_labels, autopct='%1.1f%%', colors=colors, startangle=140)

# Arabic title
title = "توزيع الوظائف حسب الجنس"
plt.title(get_display(arabic_reshaper.reshape(title)))

# Show the plot
plt.show()

# %% [raw]
# There is some gender preference in job postings, but a significant proportion (39.3%) is open to both genders.
# However, male-preferred job postings are slightly more than female-preferred ones.

# %% [markdown]
# # Q3 - What is the expected salary range for fresh graduates?

# %%
# Filter job postings for fresh graduates (experience = 0)
fresh_grads = job_posts[job_posts['experience_years'] == 0]

# Get salary statistics
min_salary = fresh_grads['salary'].min()
max_salary = fresh_grads['salary'].max()
avg_salary = fresh_grads['salary'].mean()
median_salary = fresh_grads['salary'].median()

print(f"Expected Salary Range for Fresh Graduates: {min_salary} - {max_salary}")
print(f"Average Salary: {avg_salary:.2f}")
print(f"Median Salary: {median_salary:.2f}")

# Arabic labels and title
title = "توزيع رواتب الخريجين الجدد"
xlabel = "الراتب"
ylabel = "عدد الوظائف"

reshaped_title = get_display(arabic_reshaper.reshape(title))
reshaped_xlabel = get_display(arabic_reshaper.reshape(xlabel))
reshaped_ylabel = get_display(arabic_reshaper.reshape(ylabel))

# Plot histogram
plt.figure(figsize=(8, 5))
sns.histplot(fresh_grads['salary'], bins=10, kde=True, color='purple')

plt.title(reshaped_title, fontsize=14)
plt.xlabel(reshaped_xlabel, fontsize=12)
plt.ylabel(reshaped_ylabel, fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Expected Salary Range for Fresh Graduates: 3000.0 - 12325.0
# Average Salary: 4729.54
# Median Salary: 4000.00

# %% [markdown]
# # Q4 - Are job opportunities predominantly targeted at individuals with experience, or is there room for fresh graduates as well?

# %%
# Count job postings based on required experience years
experience_counts = job_posts['experience_years'].value_counts().sort_index()

# Categorize into "Fresh Graduates" (0 years) and "Experienced" (>0 years)
fresh_grads_count = experience_counts.get(0, 0)
experienced_count = experience_counts.drop(0).sum()

# Data for plotting
categories = ["الخريجون الجدد", "ذوي الخبرة"]
values = [fresh_grads_count, experienced_count]

# Arabic text reshaping
reshaped_categories = [get_display(arabic_reshaper.reshape(cat)) for cat in categories]
title = get_display(arabic_reshaper.reshape("توزيع الوظائف حسب الخبرة المطلوبة"))

# Plot bar chart
plt.figure(figsize=(7, 5))
sns.barplot(x=reshaped_categories, y=values, palette=["#6a0dad", "#dda0dd"])

# Set labels in Arabic
plt.title(title, fontsize=14)

# Show percentage values on bars
for i, v in enumerate(values):
    plt.text(i, v + 5, f"{(v / sum(values) * 100):.1f}%", ha='center', fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\rahaf\AppData\Local\Temp\ipykernel_13100\2081080893.py:18: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [raw]
# Based on the chart, 57.5% of job opportunities are available for fresh graduates, while 42.5% require experienced candidates.
#
# This suggests that there is a significant number of opportunities for fresh graduates, indicating that the job market is relatively open to newcomers.
# However, a substantial portion still prefers experienced individuals, meaning prior experience remains valuable.

# %% [markdown]
# # Extra Questions

# %% [markdown]
# ## Q5 - Which industries have the highest number of job postings?

# %%
# Count job postings per industry
industry_counts = job_posts['eco_activity'].value_counts().head(10)  # Top 10 industries

# Reshape Arabic text for proper display
industry_labels = [get_display(arabic_reshaper.reshape(ind)) for ind in industry_counts.index]

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.barh(industry_labels, industry_counts.values, color='#6a0dad')

# Formatting
plt.xlabel(get_display(arabic_reshaper.reshape("عدد الوظائف")))
plt.ylabel(get_display(arabic_reshaper.reshape("الصناعة")))
plt.title(get_display(arabic_reshaper.reshape("أعلى الصناعات من حيث عدد الوظائف")))

# Show values on bars
for index, value in enumerate(industry_counts.values):
    plt.text(value, index, str(value), va='center', fontsize=12, fontweight='bold')

plt.gca().invert_yaxis()  # Invert to have the highest on top
plt.show()

# %% [markdown]
# ## Q6 - What are the top 10 job titles with the highest number of postings, and how do they vary by gender?

# %%
# Group job postings by job title and gender, then get the top 10 by total count
top_10_jobs = job_posts.groupby(['job_title', 'gender']).size().unstack().sum(axis=1).nlargest(10).index
industry_gender_counts = job_posts[job_posts['job_title'].isin(top_10_jobs)].groupby(['job_title', 'gender']).size().unstack()

# Arabic text reshaping for proper display
industry_labels = [get_display(arabic_reshaper.reshape(ind)) for ind in industry_gender_counts.index]
gender_labels = [get_display(arabic_reshaper.reshape(g)) for g in industry_gender_counts.columns]

# Colors for genders
colors = ['#6a0dad', '#b19cd9', '#dda0dd']

# Plot grouped bar chart
plt.figure(figsize=(12, 7))
bar_width = 0.3  # Width of bars
indices = np.arange(len(industry_gender_counts))

for i, gender in enumerate(industry_gender_counts.columns):
    plt.bar(indices + i * bar_width, industry_gender_counts[gender], width=bar_width, label=get_display(arabic_reshaper.reshape(gender)), color=colors[i])

# Formatting
plt.xticks(indices + bar_width / 2, industry_labels, rotation=45, ha='right')
plt.xlabel(get_display(arabic_reshaper.reshape("المسمى الوظيفي")))
plt.ylabel(get_display(arabic_reshaper.reshape("عدد الوظائف")))
plt.title(get_display(arabic_reshaper.reshape("توزيع الوظائف حسب الجنس والمسمى الوظيفي (أعلى 10 وظائف)")))
plt.legend()

# Show plot
plt.show()
